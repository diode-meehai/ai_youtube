# %% [markdown]
# # 1. Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import operator

import imageio
import glob
import random
import time

# %% [markdown]
# # 2. Write Function

# %% [markdown]
# ## 2.1 Linear Regression

# %%
def LR_find_r(X, Y):
    Xmean = X.mean()
    Ymean = Y.mean()
    fraction = ((X - Xmean)*(Y - Ymean)).sum()
    denorminator = np.sqrt(((X - Xmean)**2).sum()*((Y - Ymean)**2).sum())
    r = fraction/denorminator
    return r

# %%
def LR_find_ab(X, Y):
    XY = X*Y
    X2 = X**2
    Xmean = X.mean()
    Ymean = Y.mean()
    XYmean = XY.mean()
    X2mean = X2.mean()
    denorminator = X2mean - Xmean**2
    a = (XYmean - Xmean*Ymean)/denorminator
    b = (X2mean*Ymean - Xmean*XYmean)/denorminator
    return a, b

# %%
def LR_find_Yhat(X, a, b):
    Yhat = a*X + b
    return Yhat

# %% [markdown]
# ## 2.2 Multiple Regression

# %%
def MR_create_Xb(X):
    N = X.shape[0]
    ones = np.ones([N, 1])
    Xb = np.hstack([ones, X])
    return Xb

# %%
def MR_find_W(X, Y):
    Xb = MR_create_Xb(X)
    front = inv(np.dot(Xb.T, Xb))
    back = np.dot(X.T, Y)
    W = np.dot(front, back)
    return W

# %%
def MR_find_Yhat(X, W):
    Xb = MR_create_Xb(X)
    Yhat = np.dot(Xb, W)
    return Yhat

# %%
def MR_find_W_local(X, Y, epoch = 1000, lr = 0.01, batch_size = 64, lambda1 = 0, lambda2 = 0):
    Xb = MR_create_Xb(X)
    N = Xb.shape[0]
    D_1 = Xb.shape[1]
    W = np.random.randn(D_1, 1)/np.sqrt(D_1)
    error_list = []
    for i in range(epoch):
        #============== Batch Mode =============#
        if batch_size == N: #Batch
            Yhat = MR_find_Yhat(X, W)
            error = find_error(Y, Yhat, 'SSE')
            error_list.append(error)
            S = np.dot(Xb.T, Y - Yhat)
        elif batch_size != N: #Batch Mode(Mini, Stochastic)
            X_mb, Y_mb = shuffle(X, Y, N, batch_size) #===shuffle===#
            Xb_mb = MR_create_Xb(X_mb)
            Yhat_mb = MR_find_Yhat(X_mb, W)
            error = find_error(Y_mb, Yhat_mb, 'SSE')
            error_list.append(error)
            S = np.dot(Xb_mb.T, Y_mb - Yhat_mb)
        W = W + (lr/batch_size)*S - lambda1*np.sign(W) - lambda2*W
    return W, error_list

# %% [markdown]
# ## 2.3 Logistic Regression

# %%
def LoR_create_Xb(X):
    N = X.shape[0]
    ones = np.ones([N, 1])
    Xb = np.hstack([ones, X])
    return Xb

# %%
def LoR_find_W_local(X, Y, epoch = 1000, lr = 1, batch_size = 64, lambda1 = 0, lambda2 = 0):
    Xb = LoR_create_Xb(X)
    N = Xb.shape[0]
    D_1 = Xb.shape[1]
    W = np.random.randn(D_1, 1)/np.sqrt(D_1)
    error_list = []
    for i in range(epoch):
        #============== Batch Mode =============#
        if batch_size == N:   #Batch
            Yhat = LoR_find_Yhat(X, W)
            error = find_error(Y, Yhat, 'Entropy')
            error_list.append(error)
            S = np.dot(Xb.T, Y - Yhat)
        elif batch_size != N:  #Batch Mode(Mini, Stochastic)
            X_mb, Y_mb = shuffle(X, Y, N, batch_size) #===shuffle===#
            Xb_mb = LoR_create_Xb(X_mb)
            Yhat_mb = LoR_find_Yhat(Xb_mb, W)
            error = find_error(Y_mb, Yhat_mb, 'Entropy')
            error_list.append(error)
            S = np.dot(Xb_mb.T, Y_mb - Yhat_mb)
        W = W + (lr/batch_size)*S - lambda1*np.sign(W) - lambda2*W
    return W, error_list

# %%
def LoR_find_Yhat(X, W):
    Xb = LoR_create_Xb(X)
    Z = np.dot(Xb, W)
    Yhat = 1/(1 + np.exp(-Z))
    return Yhat

# %%
def LoR_find_W_local_mul_class(X, Y, epoch = 1000, lr = 1, batch_size = 64, lambda1 = 0, lambda2 = 0):
    Xb = LoR_create_Xb(X)
    N = Xb.shape[0]
    D_1 = Xb.shape[1]
    K = Y.shape[1]
    W = np.random.randn(D_1, K)/np.sqrt(D_1)
    error_list = []
    for i in range(epoch):
        #============== Batch Mode =============#
        if batch_size == N:   #Batch
            Yhat = LoR_find_Yhat_mul_class(X, W)
            error = find_error(Y, Yhat, 'Entropy')
            error_list.append(error)
            S = np.dot(Xb.T, Y-Yhat)
        elif batch_size != N: #Batch Mode(Mini, Stochastic)
            X_mb, Y_mb = shuffle(X, Y, N, batch_size) #===shuffle===#
            Xb_mb = LoR_create_Xb(X_mb)
            Yhat_mb = LoR_find_Yhat_mul_class(X_mb, W)
            error = find_error(Y_mb, Yhat_mb, 'Entropy')
            error_list.append(error)
            S = np.dot(Xb_mb.T, Y-mb - Yhat_mb)
        W = W + (lr/batch_size)*S - lambda1*np.sign(W) - lambda2*W
    return W, error_list

# %%
def LoR_find_Yhat_mul_class(X, W):
    Xb = LoR_create_Xb(X)
    Z = np.dot(Xb, W)
    Yhat = np.exp(Z)/np.exp(Z).sum(axis=1, keepdims = True)
    return Yhat

# %% [markdown]
# ## 2.4 Neural Network

# %%
def NN_create_WB(A0, HL):
    W = []
    B = []
    for i in range(len(HL)):
        if i == 0:
            W_i = np.random.randn(A0.shape[1], HL[0])/np.sqrt(HL[0])
        else:
            W_i = np.random.randn(HL[i-1], HL[i])/np.sqrt(HL[i])
        B_i = np.random.randn(1, HL[i])/np.sqrt(HL[i])
        W.append(W_i)
        B.append(B_i)
    return W, B

# %%
def NNR_find_WB(A0, T, HL, AF, epoch = 1000, lr = 0.01, batch_size = 64, lambda1 = 0, lambda2 = 0, dropout = False, prob_drop = [0]):
    L = len(HL)
    N = A0.shape[0]
    W, B = NN_create_WB(A0, HL)
    error_list = []
    for i in range(epoch):
        #============== Batch Mode =============#
        if batch_size == N: #Batch
            Z, A = NN_forward(A0, W, B, AF)
            error = find_error(T, A[-1], 'SSE')
            error_list.append(error)
            SW, SB = NNR_backpropagation(A0, W, B, Z, A, T, AF, dropout, prob_drop)
            
        elif batch_size != N:    #Batch Mode(Mini, Stochastic)
            A0_mb, T_mb = shuffle(A0, T, N, batch_size)   #===shuffle===#
            Z_mb, A_mb = NN_forward(A0_mb, W, B, AF)
            error = find_error(T_mb, A_mb[-1], 'SSE')
            error_list.append(error)
            SW, SB = NNR_backpropagation(A0_mb, W, B, Z_mb, A_mb, T_mb, AF, dropout, prob_drop)
        for j in range(L):
            W[j] = W[j] + (lr/batch_size)*SW[j] - lambda1*np.sign(W[j]) - lambda2*W[j]
            B[j] = B[j] + (lr/batch_size)*SB[j] - lambda1*np.sign(B[j]) - lambda2*B[j]
    return W, B, error_list

# %%
def NNC_find_WB(A0, T, HL, AF, epoch = 1000, lr = 0.01, batch_size = 64, lambda1 = 0, lambda2 = 0, dropout = False, prob_drop = [0]):
    L = len(HL)
    N = A0.shape[0]
    W, B = NN_create_WB(A0, HL)
    error_list = []
    for i in range(epoch):
        #============== Batch Mode =============#
        if batch_size == N:  #Batch
            Z, A = NN_forward(A0, W, B, AF)
            error = find_error(T, A[-1], 'Entropy')
            error_list.append(error)
            SW, SB = NNC_backpropagation(A0, W, B, Z, A, T, AF, dropout, prob_drop)
        elif batch_size != N: #Batch Mode(Mini, Stochastic)
            A0_mb, T_mb = shuffle(A0, T, N, batch_size)   #===shuffle===#
            Z_mb, A_mb = NN_forward(A0_mb, W, B, AF)
            error = find_error(T_mb, A_mb[-1], 'Entropy')
            error_list.append(error)
            SW, SB = NNC_backpropagation(A0_mb, W, B, Z_mb, A_mb, T_mb, AF, dropout, prob_drop)
        for j in range(L):
            W[j] = W[j] + (lr/batch_size)*SW[j] - lambda1*np.sign(W[j]) - lambda2*W[j]
            B[j] = B[j] + (lr/batch_size)*SB[j] - lambda1*np.sign(B[j]) - lambda2*B[j]
    return W, B, error_list

# %%
def NN_forward(A0, W, B, AF):
    Z = []
    A = []
    for i in range(len(AF)):
        if i == 0:
            Z_i = np.dot(A0, W[i]) + B[i]
        else:
            Z_i = np.dot(A[-1], W[i]) + B[i]
        A_i = NN_compute_A(Z_i, AF[i])
        Z.append(Z_i)
        A.append(A_i)
    return Z, A

# %%
def NN_compute_A(Z_i, af):
    if type(af) == str:
        if af == 'sigmoid':
            A_i = 1/(1 + np.exp(-Z_i))
        elif af == 'tanh':
            A_i = (np.exp(Z_i) - np.exp(-Z_i))/(np.exp(Z_i) + np.exp(-Z_i))
        elif af == 'ReLU':
            A_i = Z_i * (Z_i > 0)
        elif af == 'softmax':
            A_i = np.exp(Z_i)/np.exp(Z_i).sum(axis=1, keepdims = True)
    elif type(af) == list:
        if af[0] == 'PReLU':
            A_i = Z_i * (Z_i > 0) + af[1] * Z_i * (Z_i <= 0)
    return A_i

# %%
#=================== Regression =======================#
#---- W(m) = W(m) + (α* A(m-1)^T *Err(m))/N -----#
def NNR_backpropagation(A0, W, B, Z, A, T, AF, dropout, prob_drop):
    L = len(AF)
    SW = []
    SB = []
    
    #---- dropout Node => W(m) ----#
    if dropout == True:
        DN = NN_random_DN(HL, prob_drop)
        
    for i in range(L - 1, -1, -1): #ย้อนกลับทีละหนึ่ง Step หลังไปหน้า (out -> in) (-1)
        if i == L - 1:
            Delta_i = T - A[-1] #layer แรก (output) δ(m) = T - A(m)
        else:
            Delta_i = np.dot(Err_i, W[i+1].T) # δ(m) = Err(m+1)*W(m+1)^T
            
        Diff_i = NN_compute_Diff(Z[i], A[i], AF[i]) # Diff -> Activation function
        Err_i = NN_compute_Err(Delta_i, Diff_i)  #Err(m+1) = δ(m) * Diff(m)
        
        #---- W(m) ---#
        if dropout == False:
            if i != 0:
                SW_i = np.dot(A[i-1].T, Err_i) #layer ต่อๆมา # W(m) = A(m-1)^T *Err(m)
            else:
                SW_i = np.dot(A0.T, Err_i) #layer แรก (output) # W(1) = A(0)^T *Err(1)
            SB_i = Err_i.sum(axis=0) #รวมกันแนวตั้ง
        
        #---- dropout W(m) ----#
        elif dropout == True:
            if i != 0:
                SW_i = np.dot((A[i-1]*DN[i-1]).T, Err_i) #layer ต่อๆมา # W(m) = A(m-1)^T *Err(m)
            else:
                SW_i = np.dot(A0.T, Err_i) #layer แรก (output) # W(1) = A(0)^T *Err(1)
            if i == L - 1:
                SB_i = Err_i.sum(axis=0) #รวมกันแนวตั้ง Layer สุดท้าย
            else:
                SB_i = (Err_i*DN[i]).sum(axis=0) #รวมกันแนวตั้ง
                
        SW.append(SW_i) # Err_i -> SW_i -> SW -> W(m) or Wight
        SB.append(SB_i) # bias
    return SW[::-1], SB[::-1] # -1 กลับด้าน Array matrix ให้เรียง forward

# %%
#=================== Classification =======================#
#---- W(m) = W(m) + (α* A(m-1)^T *Err(m))/N -----#
def NNC_backpropagation(A0, W, B, Z, A, T, AF, dropout, prob_drop):
    L = len(AF)
    SW = []
    SB = []
    
    #---- dropout Node => W(m) ----#
    if dropout == True:
        DN = NN_random_DN(HL, prob_drop)
        
    for i in range(L - 1, -1, -1): #ย้อนกลับทีละหนึ่ง Step หลังไปหน้า (out -> in) (-1)
        if i == L - 1:
            Delta_i = T - A[i] #layer แรก (output) δ(m) = T - A(m)
            Diff_i = 1  # Diff_i = 1 ตามการ Diff simoid function ใน layer แรก (output)
        else:
            Delta_i = np.dot(Err_i, W[i+1].T)   # δ(m) = Err(m+1)*W(m+1)^T
            Diff_i = NN_compute_Diff(Z[i], A[i], AF[i])   # Diff -> Activation function  
        
        Err_i = NN_compute_Err(Delta_i, Diff_i)   #Err(m+1) = δ(m) * Diff(m)
        
         #---- W(m) ---#
        if dropout == False:
            if i != 0:
                SW_i = np.dot(A[i-1].T, Err_i) #layer ต่อๆมา # W(m) = A(m-1)^T *Err(m)
            else:
                SW_i = np.dot(A0.T, Err_i) #layer แรก (output) # W(1) = A(0)^T *Err(1)
            SB_i = Err_i.sum(axis=0)  #รวมกันแนวตั้ง
        
        #---- dropout W(m) ----#
        elif dropout == True:
            if i != 0:
                SW_i = np.dot((A[i-1]*DN[i-1]).T, Err_i) #layer ต่อๆมา # W(m) = A(m-1)^T *Err(m)
            else:
                SW_i = np.dot(A0.T, Err_i) #layer แรก (output) # W(1) = A(0)^T *Err(1)
            if i == L - 1:
                SB_i = Err_i.sum(axis=0)  #รวมกันแนวตั้ง
            else:
                SB_i = (Err_i*DN[i]).sum(axis=0)  #รวมกันแนวตั้ง
        
        SW.append(SW_i)  # Err_i -> SW_i -> SW -> W(m) or Wight
        SB.append(SB_i) # bias
    return SW[::-1], SB[::-1] # -1 กลับด้าน Array matrix ให้เรียง forward

# %%
#https://phyblas.hinaboshi.com/numa15
def NN_random_DN(HL, prob_drop):
    DN = []
    for i in range(len(HL)):
        Dropout_Node = np.random.choice([False, True], [1, HL[i]], p = [prob_drop[i], 1 - prob_drop[i]])
        DN.append(Dropout_Node)
    return DN

# %%
def NN_compute_Diff(Z_i, A_i, af):
    if type(af) == str:
        if af == 'sigmoid':
            Diff_i = A_i * (1 - A_i)
        elif af == 'tanh':
            Diff_i = 1 - A_i**2
        elif af == 'ReLU':
            Diff_i = (Z_i > 0)
    elif type(af) == list:
        if af[0] == 'PReLU':
            Diff_i = (Z_i > 0) + af[1] * (Z_i <= 0)
    return Diff_i

# %%
def NN_compute_Err(Delta_i, Diff_i):
    Err_i = Delta_i * Diff_i
    return Err_i

# %% [markdown]
# ## 2.5 Error Function

# %%
def find_error(Y, Yhat, TypeOfError):
    if TypeOfError == 'SSE':
        error = find_SSE(Y, Yhat)
    elif TypeOfError == 'MSE':
        error = find_MSE(Y, Yhat)
    elif TypeOfError == 'MAE':
        error = find_MAE(Y, Yhat)
    elif TypeOfError == 'MAPE':
        error = find_MAPE(Y, Yhat)
    elif TypeOfError == 'Entropy':
        error = find_Entropy(Y, Yhat)
    elif TypeOfError == 'Binary':
        error = find_error_bin_class(Y, Yhat)
    elif TypeOfError == 'Multiclass':
        error = find_error_mul_class(Y, Yhat)
    return error

# %%
def find_SSE(Y, Yhat):
    SSE = ((Y - Yhat)**2).sum()
    return SSE

# %%
def find_MSE(Y, Yhat):
    N = Y.shape[0]
    SSE = ((Y - Yhat)**2).sum()
    MSE = SSE/N
    return MSE

# %%
def find_MAE(Y, Yhat):
    N = Y.shape[0]
    MAE = (np.abs(Y - Yhat)).sum()/N
    return MAE

# %%
def find_MAPE(Y, Yhat):
    N = Y.shape[0]
    MAPE = np.abs((Y - Yhat)/Y).sum()*100/N
    return MAPE

# %%
def find_Entropy(Y, Yhat):
    error = (-Y*np.log(Yhat)).sum()
    return error

# %%
def find_error_bin_class(Y, Yhat):
    N = Y.shape[0]
    _Y = np.round(Y, 0)
    _Yhat = np.round(Yhat, 0)
    error = 100*(_Y != _Yhat).sum()/N
    return error

# %%
def find_error_mul_class(Y, Yhat):
    N = Y.shape[0]
    Y_argmax = np.argmax(Y, axis=1)
    Yhat_argmax = np.argmax(Yhat, axis=1)
    error = 100*(Y_argmax != Yhat_argmax).sum()/N
    return error

# %% [markdown]
# ## 2.6 Normalization

# %% [markdown]
# ### 2.6.1 Finding _min, _max, _mean, _std, _ed

# %%
def min4norm(Data):
    _min = Data.min(axis=0)
    return _min.reshape(1, -1)

# %%
def max4norm(Data):
    _max = Data.max(axis=0)
    return _max.reshape(1, -1)

# %%
def mean4norm(Data):
    _mean = Data.mean(axis=0)
    return _mean.reshape(1, -1)

# %%
def std4norm(Data):
    _std = Data.std(axis=0)
    return _std.reshape(1, -1)

# %%
def ed4norm(Data):
    _ed = np.sqrt((Data**2).sum(axis=0))
    return _ed.reshape(1, -1)

# %% [markdown]
# ### 2.6.2 Normalization

# %%
def minmaxNorm(Data, _min, _max):
    Data_Norm = (Data - _min)/(_max - _min)
    return Data_Norm

# %%
def rescale(Data, _min, _max, min_norm, max_norm):
    Data_Norm = (max_norm - min_norm)*((Data - _min)/(_max - _min)) + min_norm
    return Data_Norm

# %%
def meanNorm(Data, _min, _max, _mean):
    Data_Norm = (Data - _mean)/(_max - _min)
    return Data_Norm

# %%
def standardization(Data, _mean, _std):
    Data_Norm = (Data - _mean)/_std
    return Data_Norm

# %%
def SUL(Data, _ed):
    Data_Norm = Data/_ed
    return Data_Norm

# %% [markdown]
# ### 2.6.3 Denormalization

# %%
def de_minmaxNorm(Data_Norm, _min, _max):
    Data = Data_Norm*(_max - _min) + _min
    return Data

# %%
def de_rescale(Data_Norm, _min, _max, min_norm, max_norm):
    Data = (_max - _min)*((Data_Norm - min_norm)/(max_norm - min_norm)) + _min
    return Data

# %%
def de_meanNorm(Data_Norm, _min, _max, _mean):
    Data = Data_Norm*(_max - _min) + _mean
    return Data

# %%
def de_standardization(Data_Norm, _mean, _std):
    Data = Data_Norm*_std + _mean
    return Data

# %%
def de_SUL(Data_Norm, _ed):
    Data = Data_Norm*_ed
    return Data

# %% [markdown]
# ## 2.7 ETC

# %%
def create_onehot_target(label):
    K = len(np.unique(label))
    N = label.shape[0]
    onehot = np.zeros([N, K])
    for i in range(N):
        onehot[i, label[i, 0]] = 1
    return onehot

# %%
def shuffle(X, Y, N, batch_size):
    r = random.sample(range(N), batch_size)
    X_mb = X[r]
    Y_mb = Y[r]
    return X_mb, Y_mb

# %% [markdown]
# # 3. Normalization

# %%
def min4norm(Data):
    _min = Data.min(axis=0)
    return _min.reshape(1, -1)

# %%
def max4norm(Data):
    _max = Data.max(axis=0)
    return _max.reshape(1, -1)

# %%
def mean4norm(Data):
    _mean = Data.mean(axis=0)
    return _mean.reshape(1, -1)

# %%
def std4norm(Data):
    _std = Data.std(axis=0)
    return _std.reshape(1, -1)

# %%
def ed4norm(Data):
    _ed = np.sqrt((Data**2).sum(axis=0))
    return _ed.reshape(1, -1)

# %%
def minmaxNorm(Data, min_norm, max_norm):
    Data_Norm = (Data - min_norm)/(max_norm - min_norm)
    return Data_Norm

# %%
def meanNorm(Data, min_norm, max_norm, mean_norm):
    Data_Norm = (Data - mean_norm)/(max_norm - min_norm)
    return Data_Norm

# %%
def standardization(Data, mean_norm, std_norm):
    Data_Norm = (Data - mean_norm)/std_norm
    return Data_Norm

# %%
def SUL(Data, ed_norm):
    Data_Norm = Data/ed_norm
    return Data_Norm

# %%
def de_minmaxNorm(Data_Norm, min_norm, max_norm):
    Data = Data_Norm*(max_norm - min_norm) + min_norm
    return Data

# %%
def de_meanNorm(Data_Norm, min_norm, max_norm, mean_norm):
    Data = Data_Norm*(max_norm - min_norm) + mean_norm
    return Data

# %%
def de_standardization(Data_Norm, mean_norm, std_norm):
    Data = Data_Norm*std_norm + mean_norm
    return Data

# %%
def de_SUL(Data_Norm, ed_norm):
    Data = Data_Norm*ed_norm
    return Data

# %% [markdown]
# # 3. Read Data & Prepare Data

# %%
glob.glob("MNIST/train/*.png")
# Out:
# ['MNIST/train\\000000-num5.png',
#  'MNIST/train\\000001-num0.png',
#  'MNIST/train\\000002-num4.png',
#  'MNIST/train\\000003-num1.png',
#  'MNIST/train\\000004-num9.png',
#  'MNIST/train\\000005-num2.png',
#  'MNIST/train\\000006-num1.png',
#  'MNIST/train\\000007-num3.png',
#  'MNIST/train\\000008-num1.png',
#  'MNIST/train\\000009-num4.png',
#  'MNIST/train\\000010-num3.png',
#  'MNIST/train\\000011-num5.png',
#  'MNIST/train\\000012-num3.png',
#  'MNIST/train\\000013-num6.png',
#  'MNIST/train\\000014-num1.png',
#  'MNIST/train\\000015-num7.png',
#  'MNIST/train\\000016-num2.png',
#  'MNIST/train\\000017-num8.png',
#  'MNIST/train\\000018-num6.png',
#  'MNIST/train\\000019-num9.png',
#  'MNIST/train\\000020-num4.png',
#  'MNIST/train\\000021-num0.png',
#  'MNIST/train\\000022-num9.png',
#  'MNIST/train\\000023-num1.png',
#  'MNIST/train\\000024-num1.png',
#  'MNIST/train\\000025-num2.png',
#  'MNIST/train\\000026-num4.png',
#  'MNIST/train\\000027-num3.png',
#  'MNIST/train\\000028-num2.png',
#  'MNIST/train\\000029-num7.png',
#  'MNIST/train\\000030-num3.png',
#  'MNIST/train\\000031-num8.png',
#  'MNIST/train\\000032-num6.png',
#  'MNIST/train\\000033-num9.png',
#  'MNIST/train\\000034-num0.png',
#  'MNIST/train\\000035-num5.png',
#  'MNIST/train\\000036-num6.png',
#  'MNIST/train\\000037-num0.png',
#  'MNIST/train\\000038-num7.png',
#  'MNIST/train\\000039-num6.png',
#  'MNIST/train\\000040-num1.png',
#  'MNIST/train\\000041-num8.png',
#  'MNIST/train\\000042-num7.png',
#  'MNIST/train\\000043-num9.png',
#  'MNIST/train\\000044-num3.png',
#  'MNIST/train\\000045-num9.png',
#  'MNIST/train\\000046-num8.png',
#  'MNIST/train\\000047-num5.png',
#  'MNIST/train\\000048-num9.png',
#  'MNIST/train\\000049-num3.png',
#  'MNIST/train\\000050-num3.png',
#  'MNIST/train\\000051-num0.png',
#  'MNIST/train\\000052-num7.png',
#  'MNIST/train\\000053-num4.png',
#  'MNIST/train\\000054-num9.png',
#  'MNIST/train\\000055-num8.png',
#  'MNIST/train\\000056-num0.png',
#  'MNIST/train\\000057-num9.png',
#  'MNIST/train\\000058-num4.png',
#  'MNIST/train\\000059-num1.png',
#  'MNIST/train\\000060-num4.png',
#  'MNIST/train\\000061-num4.png',
#  'MNIST/train\\000062-num6.png',
#  'MNIST/train\\000063-num0.png',
#  'MNIST/train\\000064-num4.png',
#  'MNIST/train\\000065-num5.png',
#  'MNIST/train\\000066-num6.png',
#  'MNIST/train\\000067-num1.png',
#  'MNIST/train\\000068-num0.png',
#  'MNIST/train\\000069-num0.png',
#  'MNIST/train\\000070-num1.png',
#  'MNIST/train\\000071-num7.png',
#  'MNIST/train\\000072-num1.png',
#  'MNIST/train\\000073-num6.png',
#  'MNIST/train\\000074-num3.png',
#  'MNIST/train\\000075-num0.png',
#  'MNIST/train\\000076-num2.png',
#  'MNIST/train\\000077-num1.png',
#  'MNIST/train\\000078-num1.png',
#  'MNIST/train\\000079-num7.png',
#  'MNIST/train\\000080-num9.png',
#  'MNIST/train\\000081-num0.png',
#  'MNIST/train\\000082-num2.png',
#  'MNIST/train\\000083-num6.png',
#  'MNIST/train\\000084-num7.png',
#  'MNIST/train\\000085-num8.png',
#  'MNIST/train\\000086-num3.png',
#  'MNIST/train\\000087-num9.png',
#  'MNIST/train\\000088-num0.png',
#  'MNIST/train\\000089-num4.png',
#  'MNIST/train\\000090-num6.png',
#  'MNIST/train\\000091-num7.png',
#  'MNIST/train\\000092-num4.png',
#  'MNIST/train\\000093-num6.png',
#  'MNIST/train\\000094-num8.png',
#  'MNIST/train\\000095-num0.png',
#  'MNIST/train\\000096-num7.png',
#  'MNIST/train\\000097-num8.png',
#  'MNIST/train\\000098-num3.png',
#  'MNIST/train\\000099-num1.png',
#  'MNIST/train\\000100-num5.png',
#  'MNIST/train\\000101-num7.png',
#  'MNIST/train\\000102-num1.png',
#  'MNIST/train\\000103-num7.png',
#  'MNIST/train\\000104-num1.png',
#  'MNIST/train\\000105-num1.png',
#  'MNIST/train\\000106-num6.png',
#  'MNIST/train\\000107-num3.png',
#  'MNIST/train\\000108-num0.png',
#  'MNIST/train\\000109-num2.png',
#  'MNIST/train\\000110-num9.png',
#  'MNIST/train\\000111-num3.png',
#  'MNIST/train\\000112-num1.png',
#  'MNIST/train\\000113-num1.png',
#  'MNIST/train\\000114-num0.png',
#  'MNIST/train\\000115-num4.png',
#  'MNIST/train\\000116-num9.png',
#  'MNIST/train\\000117-num2.png',
#  'MNIST/train\\000118-num0.png',
#  'MNIST/train\\000119-num0.png',
#  'MNIST/train\\000120-num2.png',
#  'MNIST/train\\000121-num0.png',
#  'MNIST/train\\000122-num2.png',
#  'MNIST/train\\000123-num7.png',
#  'MNIST/train\\000124-num1.png',
#  'MNIST/train\\000125-num8.png',
#  'MNIST/train\\000126-num6.png',
#  'MNIST/train\\000127-num4.png',
#  'MNIST/train\\000128-num1.png',
#  'MNIST/train\\000129-num6.png',
#  'MNIST/train\\000130-num3.png',
#  'MNIST/train\\000131-num4.png',
#  'MNIST/train\\000132-num5.png',
#  'MNIST/train\\000133-num9.png',
#  'MNIST/train\\000134-num1.png',
#  'MNIST/train\\000135-num3.png',
#  'MNIST/train\\000136-num3.png',
#  'MNIST/train\\000137-num8.png',
#  'MNIST/train\\000138-num5.png',
#  'MNIST/train\\000139-num4.png',
#  'MNIST/train\\000140-num7.png',
#  'MNIST/train\\000141-num7.png',
#  'MNIST/train\\000142-num4.png',
#  'MNIST/train\\000143-num2.png',
#  'MNIST/train\\000144-num8.png',
#  'MNIST/train\\000145-num5.png',
#  'MNIST/train\\000146-num8.png',
#  'MNIST/train\\000147-num6.png',
#  'MNIST/train\\000148-num7.png',
#  'MNIST/train\\000149-num3.png',
#  'MNIST/train\\000150-num4.png',
#  'MNIST/train\\000151-num6.png',
#  'MNIST/train\\000152-num1.png',
#  'MNIST/train\\000153-num9.png',
#  'MNIST/train\\000154-num9.png',
#  'MNIST/train\\000155-num6.png',
#  'MNIST/train\\000156-num0.png',
#  'MNIST/train\\000157-num3.png',
#  'MNIST/train\\000158-num7.png',
#  'MNIST/train\\000159-num2.png',
#  'MNIST/train\\000160-num8.png',
#  'MNIST/train\\000161-num2.png',
#  'MNIST/train\\000162-num9.png',
#  'MNIST/train\\000163-num4.png',
#  'MNIST/train\\000164-num4.png',
#  'MNIST/train\\000165-num6.png',
#  'MNIST/train\\000166-num4.png',
#  'MNIST/train\\000167-num9.png',
#  'MNIST/train\\000168-num7.png',
#  'MNIST/train\\000169-num0.png',
#  'MNIST/train\\000170-num9.png',
#  'MNIST/train\\000171-num2.png',
#  'MNIST/train\\000172-num9.png',
#  'MNIST/train\\000173-num5.png',
#  'MNIST/train\\000174-num1.png',
#  'MNIST/train\\000175-num5.png',
#  'MNIST/train\\000176-num9.png',
#  'MNIST/train\\000177-num1.png',
#  'MNIST/train\\000178-num2.png',
#  'MNIST/train\\000179-num3.png',
#  'MNIST/train\\000180-num2.png',
#  'MNIST/train\\000181-num3.png',
#  'MNIST/train\\000182-num5.png',
#  'MNIST/train\\000183-num9.png',
#  'MNIST/train\\000184-num1.png',
#  'MNIST/train\\000185-num7.png',
#  'MNIST/train\\000186-num6.png',
#  'MNIST/train\\000187-num2.png',
#  'MNIST/train\\000188-num8.png',
#  'MNIST/train\\000189-num2.png',
#  'MNIST/train\\000190-num2.png',
#  'MNIST/train\\000191-num5.png',
#  'MNIST/train\\000192-num0.png',
#  'MNIST/train\\000193-num7.png',
#  'MNIST/train\\000194-num4.png',
#  'MNIST/train\\000195-num9.png',
#  'MNIST/train\\000196-num7.png',
#  'MNIST/train\\000197-num8.png',
#  'MNIST/train\\000198-num3.png',
#  'MNIST/train\\000199-num2.png',
#  'MNIST/train\\000200-num1.png',
#  'MNIST/train\\000201-num1.png',
#  'MNIST/train\\000202-num8.png',
#  'MNIST/train\\000203-num3.png',
#  'MNIST/train\\000204-num6.png',
#  'MNIST/train\\000205-num1.png',
#  'MNIST/train\\000206-num0.png',
#  'MNIST/train\\000207-num3.png',
#  'MNIST/train\\000208-num1.png',
#  'MNIST/train\\000209-num0.png',
#  'MNIST/train\\000210-num0.png',
#  'MNIST/train\\000211-num1.png',
#  'MNIST/train\\000212-num7.png',
#  'MNIST/train\\000213-num2.png',
#  'MNIST/train\\000214-num7.png',
#  'MNIST/train\\000215-num3.png',
#  'MNIST/train\\000216-num0.png',
#  'MNIST/train\\000217-num4.png',
#  'MNIST/train\\000218-num6.png',
#  'MNIST/train\\000219-num5.png',
#  'MNIST/train\\000220-num2.png',
#  'MNIST/train\\000221-num6.png',
#  'MNIST/train\\000222-num4.png',
#  'MNIST/train\\000223-num7.png',
#  'MNIST/train\\000224-num1.png',
#  'MNIST/train\\000225-num8.png',
#  'MNIST/train\\000226-num9.png',
#  'MNIST/train\\000227-num9.png',
#  'MNIST/train\\000228-num3.png',
#  'MNIST/train\\000229-num0.png',
#  'MNIST/train\\000230-num7.png',
#  'MNIST/train\\000231-num1.png',
#  'MNIST/train\\000232-num0.png',
#  'MNIST/train\\000233-num2.png',
#  'MNIST/train\\000234-num0.png',
#  'MNIST/train\\000235-num3.png',
#  'MNIST/train\\000236-num5.png',
#  'MNIST/train\\000237-num4.png',
#  'MNIST/train\\000238-num6.png',
#  'MNIST/train\\000239-num5.png',
#  'MNIST/train\\000240-num8.png',
#  'MNIST/train\\000241-num6.png',
#  'MNIST/train\\000242-num3.png',
#  'MNIST/train\\000243-num7.png',
#  'MNIST/train\\000244-num5.png',
#  'MNIST/train\\000245-num8.png',
#  'MNIST/train\\000246-num0.png',
#  'MNIST/train\\000247-num9.png',
#  'MNIST/train\\000248-num1.png',
#  'MNIST/train\\000249-num0.png',
#  'MNIST/train\\000250-num3.png',
#  'MNIST/train\\000251-num1.png',
#  'MNIST/train\\000252-num2.png',
#  'MNIST/train\\000253-num2.png',
#  'MNIST/train\\000254-num3.png',
#  'MNIST/train\\000255-num3.png',
#  'MNIST/train\\000256-num6.png',
#  'MNIST/train\\000257-num4.png',
#  'MNIST/train\\000258-num7.png',
#  'MNIST/train\\000259-num5.png',
#  'MNIST/train\\000260-num0.png',
#  'MNIST/train\\000261-num6.png',
#  'MNIST/train\\000262-num2.png',
#  'MNIST/train\\000263-num7.png',
#  'MNIST/train\\000264-num9.png',
#  'MNIST/train\\000265-num8.png',
#  'MNIST/train\\000266-num5.png',
#  'MNIST/train\\000267-num9.png',
#  'MNIST/train\\000268-num2.png',
#  'MNIST/train\\000269-num1.png',
#  'MNIST/train\\000270-num1.png',
#  'MNIST/train\\000271-num4.png',
#  'MNIST/train\\000272-num4.png',
#  'MNIST/train\\000273-num5.png',
#  'MNIST/train\\000274-num6.png',
#  'MNIST/train\\000275-num4.png',
#  'MNIST/train\\000276-num1.png',
#  'MNIST/train\\000277-num2.png',
#  'MNIST/train\\000278-num5.png',
#  'MNIST/train\\000279-num3.png',
#  'MNIST/train\\000280-num9.png',
#  'MNIST/train\\000281-num3.png',
#  'MNIST/train\\000282-num9.png',
#  'MNIST/train\\000283-num0.png',
#  'MNIST/train\\000284-num5.png',
#  'MNIST/train\\000285-num9.png',
#  'MNIST/train\\000286-num6.png',
#  'MNIST/train\\000287-num5.png',
#  'MNIST/train\\000288-num7.png',
#  'MNIST/train\\000289-num4.png',
#  'MNIST/train\\000290-num1.png',
#  'MNIST/train\\000291-num3.png',
#  'MNIST/train\\000292-num4.png',
#  'MNIST/train\\000293-num0.png',
#  'MNIST/train\\000294-num4.png',
#  'MNIST/train\\000295-num8.png',
#  'MNIST/train\\000296-num0.png',
#  'MNIST/train\\000297-num4.png',
#  'MNIST/train\\000298-num3.png',
#  'MNIST/train\\000299-num6.png',
#  'MNIST/train\\000300-num8.png',
#  'MNIST/train\\000301-num7.png',
#  'MNIST/train\\000302-num6.png',
#  'MNIST/train\\000303-num0.png',
#  'MNIST/train\\000304-num9.png',
#  'MNIST/train\\000305-num7.png',
#  'MNIST/train\\000306-num5.png',
#  'MNIST/train\\000307-num7.png',
#  'MNIST/train\\000308-num2.png',
#  'MNIST/train\\000309-num1.png',
#  'MNIST/train\\000310-num1.png',
#  'MNIST/train\\000311-num6.png',
#  'MNIST/train\\000312-num8.png',
#  'MNIST/train\\000313-num9.png',
#  'MNIST/train\\000314-num4.png',
#  'MNIST/train\\000315-num1.png',
#  'MNIST/train\\000316-num5.png',
#  'MNIST/train\\000317-num2.png',
#  'MNIST/train\\000318-num2.png',
#  'MNIST/train\\000319-num9.png',
#  'MNIST/train\\000320-num0.png',
#  'MNIST/train\\000321-num3.png',
#  'MNIST/train\\000322-num9.png',
#  'MNIST/train\\000323-num6.png',
#  'MNIST/train\\000324-num7.png',
#  'MNIST/train\\000325-num2.png',
#  'MNIST/train\\000326-num0.png',
#  'MNIST/train\\000327-num3.png',
#  'MNIST/train\\000328-num5.png',
#  'MNIST/train\\000329-num4.png',
#  'MNIST/train\\000330-num3.png',
#  'MNIST/train\\000331-num6.png',
#  'MNIST/train\\000332-num5.png',
#  'MNIST/train\\000333-num8.png',
#  'MNIST/train\\000334-num9.png',
#  'MNIST/train\\000335-num5.png',
#  'MNIST/train\\000336-num4.png',
#  'MNIST/train\\000337-num7.png',
#  'MNIST/train\\000338-num4.png',
#  'MNIST/train\\000339-num2.png',
#  'MNIST/train\\000340-num7.png',
#  'MNIST/train\\000341-num3.png',
#  'MNIST/train\\000342-num4.png',
#  'MNIST/train\\000343-num8.png',
#  'MNIST/train\\000344-num9.png',
#  'MNIST/train\\000345-num1.png',
#  'MNIST/train\\000346-num9.png',
#  'MNIST/train\\000347-num2.png',
#  'MNIST/train\\000348-num8.png',
#  'MNIST/train\\000349-num7.png',
#  'MNIST/train\\000350-num9.png',
#  'MNIST/train\\000351-num1.png',
#  'MNIST/train\\000352-num8.png',
#  'MNIST/train\\000353-num7.png',
#  'MNIST/train\\000354-num4.png',
#  'MNIST/train\\000355-num1.png',
#  'MNIST/train\\000356-num3.png',
#  'MNIST/train\\000357-num1.png',
#  'MNIST/train\\000358-num1.png',
#  'MNIST/train\\000359-num0.png',
#  'MNIST/train\\000360-num2.png',
#  'MNIST/train\\000361-num3.png',
#  'MNIST/train\\000362-num9.png',
#  'MNIST/train\\000363-num4.png',
#  'MNIST/train\\000364-num9.png',
#  'MNIST/train\\000365-num2.png',
#  'MNIST/train\\000366-num1.png',
#  'MNIST/train\\000367-num6.png',
#  'MNIST/train\\000368-num8.png',
#  'MNIST/train\\000369-num4.png',
#  'MNIST/train\\000370-num7.png',
#  'MNIST/train\\000371-num7.png',
#  'MNIST/train\\000372-num4.png',
#  'MNIST/train\\000373-num4.png',
#  'MNIST/train\\000374-num9.png',
#  'MNIST/train\\000375-num2.png',
#  'MNIST/train\\000376-num5.png',
#  'MNIST/train\\000377-num7.png',
#  'MNIST/train\\000378-num2.png',
#  'MNIST/train\\000379-num4.png',
#  'MNIST/train\\000380-num4.png',
#  'MNIST/train\\000381-num2.png',
#  'MNIST/train\\000382-num1.png',
#  'MNIST/train\\000383-num9.png',
#  'MNIST/train\\000384-num7.png',
#  'MNIST/train\\000385-num2.png',
#  'MNIST/train\\000386-num8.png',
#  'MNIST/train\\000387-num7.png',
#  'MNIST/train\\000388-num6.png',
#  'MNIST/train\\000389-num9.png',
#  'MNIST/train\\000390-num2.png',
#  'MNIST/train\\000391-num2.png',
#  'MNIST/train\\000392-num3.png',
#  'MNIST/train\\000393-num8.png',
#  'MNIST/train\\000394-num1.png',
#  'MNIST/train\\000395-num6.png',
#  'MNIST/train\\000396-num5.png',
#  'MNIST/train\\000397-num1.png',
#  'MNIST/train\\000398-num1.png',
#  'MNIST/train\\000399-num0.png',
#  'MNIST/train\\000400-num2.png',
#  'MNIST/train\\000401-num6.png',
#  'MNIST/train\\000402-num4.png',
#  'MNIST/train\\000403-num5.png',
#  'MNIST/train\\000404-num8.png',
#  'MNIST/train\\000405-num3.png',
#  'MNIST/train\\000406-num1.png',
#  'MNIST/train\\000407-num5.png',
#  'MNIST/train\\000408-num1.png',
#  'MNIST/train\\000409-num9.png',
#  'MNIST/train\\000410-num2.png',
#  'MNIST/train\\000411-num7.png',
#  'MNIST/train\\000412-num4.png',
#  'MNIST/train\\000413-num4.png',
#  'MNIST/train\\000414-num4.png',
#  'MNIST/train\\000415-num8.png',
#  'MNIST/train\\000416-num1.png',
#  'MNIST/train\\000417-num5.png',
#  'MNIST/train\\000418-num8.png',
#  'MNIST/train\\000419-num9.png',
#  'MNIST/train\\000420-num5.png',
#  'MNIST/train\\000421-num6.png',
#  'MNIST/train\\000422-num7.png',
#  'MNIST/train\\000423-num9.png',
#  'MNIST/train\\000424-num9.png',
#  'MNIST/train\\000425-num3.png',
#  'MNIST/train\\000426-num7.png',
#  'MNIST/train\\000427-num0.png',
#  'MNIST/train\\000428-num9.png',
#  'MNIST/train\\000429-num0.png',
#  'MNIST/train\\000430-num6.png',
#  'MNIST/train\\000431-num6.png',
#  'MNIST/train\\000432-num2.png',
#  'MNIST/train\\000433-num3.png',
#  'MNIST/train\\000434-num9.png',
#  'MNIST/train\\000435-num0.png',
#  'MNIST/train\\000436-num7.png',
#  'MNIST/train\\000437-num5.png',
#  'MNIST/train\\000438-num4.png',
#  'MNIST/train\\000439-num8.png',
#  'MNIST/train\\000440-num0.png',
#  'MNIST/train\\000441-num9.png',
#  'MNIST/train\\000442-num4.png',
#  'MNIST/train\\000443-num1.png',
#  'MNIST/train\\000444-num2.png',
#  'MNIST/train\\000445-num8.png',
#  'MNIST/train\\000446-num7.png',
#  'MNIST/train\\000447-num1.png',
#  'MNIST/train\\000448-num2.png',
#  'MNIST/train\\000449-num6.png',
#  'MNIST/train\\000450-num1.png',
#  'MNIST/train\\000451-num0.png',
#  'MNIST/train\\000452-num3.png',
#  'MNIST/train\\000453-num0.png',
#  'MNIST/train\\000454-num1.png',
#  'MNIST/train\\000455-num1.png',
#  'MNIST/train\\000456-num8.png',
#  'MNIST/train\\000457-num2.png',
#  'MNIST/train\\000458-num0.png',
#  'MNIST/train\\000459-num3.png',
#  'MNIST/train\\000460-num9.png',
#  'MNIST/train\\000461-num4.png',
#  'MNIST/train\\000462-num0.png',
#  'MNIST/train\\000463-num5.png',
#  'MNIST/train\\000464-num0.png',
#  'MNIST/train\\000465-num6.png',
#  'MNIST/train\\000466-num1.png',
#  'MNIST/train\\000467-num7.png',
#  'MNIST/train\\000468-num7.png',
#  'MNIST/train\\000469-num8.png',
#  'MNIST/train\\000470-num1.png',
#  'MNIST/train\\000471-num9.png',
#  'MNIST/train\\000472-num2.png',
#  'MNIST/train\\000473-num0.png',
#  'MNIST/train\\000474-num5.png',
#  'MNIST/train\\000475-num1.png',
#  'MNIST/train\\000476-num2.png',
#  'MNIST/train\\000477-num2.png',
#  'MNIST/train\\000478-num7.png',
#  'MNIST/train\\000479-num3.png',
#  'MNIST/train\\000480-num5.png',
#  'MNIST/train\\000481-num4.png',
#  'MNIST/train\\000482-num9.png',
#  'MNIST/train\\000483-num7.png',
#  'MNIST/train\\000484-num1.png',
#  'MNIST/train\\000485-num8.png',
#  'MNIST/train\\000486-num3.png',
#  'MNIST/train\\000487-num9.png',
#  'MNIST/train\\000488-num6.png',
#  'MNIST/train\\000489-num0.png',
#  'MNIST/train\\000490-num3.png',
#  'MNIST/train\\000491-num1.png',
#  'MNIST/train\\000492-num1.png',
#  'MNIST/train\\000493-num2.png',
#  'MNIST/train\\000494-num6.png',
#  'MNIST/train\\000495-num3.png',
#  'MNIST/train\\000496-num5.png',
#  'MNIST/train\\000497-num7.png',
#  'MNIST/train\\000498-num6.png',
#  'MNIST/train\\000499-num8.png',
#  'MNIST/train\\000500-num3.png',
#  'MNIST/train\\000501-num9.png',
#  'MNIST/train\\000502-num5.png',
#  'MNIST/train\\000503-num8.png',
#  'MNIST/train\\000504-num5.png',
#  'MNIST/train\\000505-num7.png',
#  'MNIST/train\\000506-num6.png',
#  'MNIST/train\\000507-num1.png',
#  'MNIST/train\\000508-num1.png',
#  'MNIST/train\\000509-num3.png',
#  'MNIST/train\\000510-num1.png',
#  'MNIST/train\\000511-num7.png',
#  'MNIST/train\\000512-num5.png',
#  'MNIST/train\\000513-num5.png',
#  'MNIST/train\\000514-num5.png',
#  'MNIST/train\\000515-num2.png',
#  'MNIST/train\\000516-num5.png',
#  'MNIST/train\\000517-num8.png',
#  'MNIST/train\\000518-num7.png',
#  'MNIST/train\\000519-num0.png',
#  'MNIST/train\\000520-num9.png',
#  'MNIST/train\\000521-num7.png',
#  'MNIST/train\\000522-num7.png',
#  'MNIST/train\\000523-num5.png',
#  'MNIST/train\\000524-num0.png',
#  'MNIST/train\\000525-num9.png',
#  'MNIST/train\\000526-num0.png',
#  'MNIST/train\\000527-num0.png',
#  'MNIST/train\\000528-num8.png',
#  'MNIST/train\\000529-num9.png',
#  'MNIST/train\\000530-num2.png',
#  'MNIST/train\\000531-num4.png',
#  'MNIST/train\\000532-num8.png',
#  'MNIST/train\\000533-num1.png',
#  'MNIST/train\\000534-num6.png',
#  'MNIST/train\\000535-num1.png',
#  'MNIST/train\\000536-num6.png',
#  'MNIST/train\\000537-num5.png',
#  'MNIST/train\\000538-num1.png',
#  'MNIST/train\\000539-num8.png',
#  'MNIST/train\\000540-num3.png',
#  'MNIST/train\\000541-num4.png',
#  'MNIST/train\\000542-num0.png',
#  'MNIST/train\\000543-num5.png',
#  'MNIST/train\\000544-num5.png',
#  'MNIST/train\\000545-num8.png',
#  'MNIST/train\\000546-num3.png',
#  'MNIST/train\\000547-num6.png',
#  'MNIST/train\\000548-num2.png',
#  'MNIST/train\\000549-num3.png',
#  'MNIST/train\\000550-num9.png',
#  'MNIST/train\\000551-num2.png',
#  'MNIST/train\\000552-num1.png',
#  'MNIST/train\\000553-num1.png',
#  'MNIST/train\\000554-num5.png',
#  'MNIST/train\\000555-num2.png',
#  'MNIST/train\\000556-num1.png',
#  'MNIST/train\\000557-num3.png',
#  'MNIST/train\\000558-num2.png',
#  'MNIST/train\\000559-num8.png',
#  'MNIST/train\\000560-num7.png',
#  'MNIST/train\\000561-num3.png',
#  'MNIST/train\\000562-num7.png',
#  'MNIST/train\\000563-num2.png',
#  'MNIST/train\\000564-num4.png',
#  'MNIST/train\\000565-num6.png',
#  'MNIST/train\\000566-num9.png',
#  'MNIST/train\\000567-num7.png',
#  'MNIST/train\\000568-num2.png',
#  'MNIST/train\\000569-num4.png',
#  'MNIST/train\\000570-num2.png',
#  'MNIST/train\\000571-num8.png',
#  'MNIST/train\\000572-num1.png',
#  'MNIST/train\\000573-num1.png',
#  'MNIST/train\\000574-num3.png',
#  'MNIST/train\\000575-num8.png',
#  'MNIST/train\\000576-num4.png',
#  'MNIST/train\\000577-num0.png',
#  'MNIST/train\\000578-num6.png',
#  'MNIST/train\\000579-num5.png',
#  'MNIST/train\\000580-num9.png',
#  'MNIST/train\\000581-num3.png',
#  'MNIST/train\\000582-num0.png',
#  'MNIST/train\\000583-num9.png',
#  'MNIST/train\\000584-num2.png',
#  'MNIST/train\\000585-num4.png',
#  'MNIST/train\\000586-num7.png',
#  'MNIST/train\\000587-num1.png',
#  'MNIST/train\\000588-num2.png',
#  'MNIST/train\\000589-num9.png',
#  'MNIST/train\\000590-num4.png',
#  'MNIST/train\\000591-num2.png',
#  'MNIST/train\\000592-num6.png',
#  'MNIST/train\\000593-num1.png',
#  'MNIST/train\\000594-num8.png',
#  'MNIST/train\\000595-num9.png',
#  'MNIST/train\\000596-num0.png',
#  'MNIST/train\\000597-num6.png',
#  'MNIST/train\\000598-num6.png',
#  'MNIST/train\\000599-num7.png',
#  'MNIST/train\\000600-num9.png',
#  'MNIST/train\\000601-num9.png',
#  'MNIST/train\\000602-num8.png',
#  'MNIST/train\\000603-num0.png',
#  'MNIST/train\\000604-num1.png',
#  'MNIST/train\\000605-num4.png',
#  'MNIST/train\\000606-num4.png',
#  'MNIST/train\\000607-num6.png',
#  'MNIST/train\\000608-num7.png',
#  'MNIST/train\\000609-num1.png',
#  'MNIST/train\\000610-num5.png',
#  'MNIST/train\\000611-num7.png',
#  'MNIST/train\\000612-num0.png',
#  'MNIST/train\\000613-num3.png',
#  'MNIST/train\\000614-num5.png',
#  'MNIST/train\\000615-num8.png',
#  'MNIST/train\\000616-num4.png',
#  'MNIST/train\\000617-num7.png',
#  'MNIST/train\\000618-num1.png',
#  'MNIST/train\\000619-num2.png',
#  'MNIST/train\\000620-num5.png',
#  'MNIST/train\\000621-num9.png',
#  'MNIST/train\\000622-num5.png',
#  'MNIST/train\\000623-num6.png',
#  'MNIST/train\\000624-num7.png',
#  'MNIST/train\\000625-num5.png',
#  'MNIST/train\\000626-num9.png',
#  'MNIST/train\\000627-num8.png',
#  'MNIST/train\\000628-num8.png',
#  'MNIST/train\\000629-num3.png',
#  'MNIST/train\\000630-num6.png',
#  'MNIST/train\\000631-num9.png',
#  'MNIST/train\\000632-num7.png',
#  'MNIST/train\\000633-num0.png',
#  'MNIST/train\\000634-num7.png',
#  'MNIST/train\\000635-num5.png',
#  'MNIST/train\\000636-num7.png',
#  'MNIST/train\\000637-num1.png',
#  'MNIST/train\\000638-num1.png',
#  'MNIST/train\\000639-num0.png',
#  'MNIST/train\\000640-num7.png',
#  'MNIST/train\\000641-num9.png',
#  'MNIST/train\\000642-num2.png',
#  'MNIST/train\\000643-num3.png',
#  'MNIST/train\\000644-num7.png',
#  'MNIST/train\\000645-num3.png',
#  'MNIST/train\\000646-num2.png',
#  'MNIST/train\\000647-num4.png',
#  'MNIST/train\\000648-num1.png',
#  'MNIST/train\\000649-num6.png',
#  'MNIST/train\\000650-num2.png',
#  'MNIST/train\\000651-num7.png',
#  'MNIST/train\\000652-num5.png',
#  'MNIST/train\\000653-num5.png',
#  'MNIST/train\\000654-num7.png',
#  'MNIST/train\\000655-num4.png',
#  'MNIST/train\\000656-num0.png',
#  'MNIST/train\\000657-num2.png',
#  'MNIST/train\\000658-num6.png',
#  'MNIST/train\\000659-num3.png',
#  'MNIST/train\\000660-num6.png',
#  'MNIST/train\\000661-num4.png',
#  'MNIST/train\\000662-num0.png',
#  'MNIST/train\\000663-num4.png',
#  'MNIST/train\\000664-num2.png',
#  'MNIST/train\\000665-num6.png',
#  'MNIST/train\\000666-num0.png',
#  'MNIST/train\\000667-num0.png',
#  'MNIST/train\\000668-num0.png',
#  'MNIST/train\\000669-num0.png',
#  'MNIST/train\\000670-num3.png',
#  'MNIST/train\\000671-num1.png',
#  'MNIST/train\\000672-num6.png',
#  'MNIST/train\\000673-num2.png',
#  'MNIST/train\\000674-num2.png',
#  'MNIST/train\\000675-num3.png',
#  'MNIST/train\\000676-num1.png',
#  'MNIST/train\\000677-num4.png',
#  'MNIST/train\\000678-num1.png',
#  'MNIST/train\\000679-num5.png',
#  'MNIST/train\\000680-num4.png',
#  'MNIST/train\\000681-num6.png',
#  'MNIST/train\\000682-num4.png',
#  'MNIST/train\\000683-num7.png',
#  'MNIST/train\\000684-num2.png',
#  'MNIST/train\\000685-num8.png',
#  'MNIST/train\\000686-num7.png',
#  'MNIST/train\\000687-num9.png',
#  'MNIST/train\\000688-num2.png',
#  'MNIST/train\\000689-num0.png',
#  'MNIST/train\\000690-num5.png',
#  'MNIST/train\\000691-num1.png',
#  'MNIST/train\\000692-num4.png',
#  'MNIST/train\\000693-num2.png',
#  'MNIST/train\\000694-num8.png',
#  'MNIST/train\\000695-num3.png',
#  'MNIST/train\\000696-num2.png',
#  'MNIST/train\\000697-num4.png',
#  'MNIST/train\\000698-num1.png',
#  'MNIST/train\\000699-num5.png',
#  'MNIST/train\\000700-num4.png',
#  'MNIST/train\\000701-num6.png',
#  'MNIST/train\\000702-num0.png',
#  'MNIST/train\\000703-num7.png',
#  'MNIST/train\\000704-num9.png',
#  'MNIST/train\\000705-num8.png',
#  'MNIST/train\\000706-num4.png',
#  'MNIST/train\\000707-num9.png',
#  'MNIST/train\\000708-num8.png',
#  'MNIST/train\\000709-num0.png',
#  'MNIST/train\\000710-num1.png',
#  'MNIST/train\\000711-num1.png',
#  'MNIST/train\\000712-num0.png',
#  'MNIST/train\\000713-num2.png',
#  'MNIST/train\\000714-num2.png',
#  'MNIST/train\\000715-num3.png',
#  'MNIST/train\\000716-num2.png',
#  'MNIST/train\\000717-num4.png',
#  'MNIST/train\\000718-num4.png',
#  'MNIST/train\\000719-num5.png',
#  'MNIST/train\\000720-num8.png',
#  'MNIST/train\\000721-num6.png',
#  'MNIST/train\\000722-num5.png',
#  'MNIST/train\\000723-num7.png',
#  'MNIST/train\\000724-num7.png',
#  'MNIST/train\\000725-num8.png',
#  'MNIST/train\\000726-num8.png',
#  'MNIST/train\\000727-num9.png',
#  'MNIST/train\\000728-num7.png',
#  'MNIST/train\\000729-num4.png',
#  'MNIST/train\\000730-num7.png',
#  'MNIST/train\\000731-num3.png',
#  'MNIST/train\\000732-num2.png',
#  'MNIST/train\\000733-num0.png',
#  'MNIST/train\\000734-num8.png',
#  'MNIST/train\\000735-num6.png',
#  'MNIST/train\\000736-num8.png',
#  'MNIST/train\\000737-num6.png',
#  'MNIST/train\\000738-num1.png',
#  'MNIST/train\\000739-num6.png',
#  'MNIST/train\\000740-num8.png',
#  'MNIST/train\\000741-num9.png',
#  'MNIST/train\\000742-num4.png',
#  'MNIST/train\\000743-num0.png',
#  'MNIST/train\\000744-num9.png',
#  'MNIST/train\\000745-num0.png',
#  'MNIST/train\\000746-num4.png',
#  'MNIST/train\\000747-num1.png',
#  'MNIST/train\\000748-num5.png',
#  'MNIST/train\\000749-num4.png',
#  'MNIST/train\\000750-num7.png',
#  'MNIST/train\\000751-num5.png',
#  'MNIST/train\\000752-num3.png',
#  'MNIST/train\\000753-num7.png',
#  'MNIST/train\\000754-num4.png',
#  'MNIST/train\\000755-num9.png',
#  'MNIST/train\\000756-num8.png',
#  'MNIST/train\\000757-num5.png',
#  'MNIST/train\\000758-num8.png',
#  'MNIST/train\\000759-num6.png',
#  'MNIST/train\\000760-num3.png',
#  'MNIST/train\\000761-num8.png',
#  'MNIST/train\\000762-num6.png',
#  'MNIST/train\\000763-num9.png',
#  'MNIST/train\\000764-num9.png',
#  'MNIST/train\\000765-num1.png',
#  'MNIST/train\\000766-num8.png',
#  'MNIST/train\\000767-num3.png',
#  'MNIST/train\\000768-num5.png',
#  'MNIST/train\\000769-num8.png',
#  'MNIST/train\\000770-num6.png',
#  'MNIST/train\\000771-num5.png',
#  'MNIST/train\\000772-num9.png',
#  'MNIST/train\\000773-num7.png',
#  'MNIST/train\\000774-num2.png',
#  'MNIST/train\\000775-num5.png',
#  'MNIST/train\\000776-num0.png',
#  'MNIST/train\\000777-num8.png',
#  'MNIST/train\\000778-num5.png',
#  'MNIST/train\\000779-num1.png',
#  'MNIST/train\\000780-num1.png',
#  'MNIST/train\\000781-num0.png',
#  'MNIST/train\\000782-num9.png',
#  'MNIST/train\\000783-num1.png',
#  'MNIST/train\\000784-num8.png',
#  'MNIST/train\\000785-num6.png',
#  'MNIST/train\\000786-num7.png',
#  'MNIST/train\\000787-num0.png',
#  'MNIST/train\\000788-num9.png',
#  'MNIST/train\\000789-num3.png',
#  'MNIST/train\\000790-num0.png',
#  'MNIST/train\\000791-num8.png',
#  'MNIST/train\\000792-num8.png',
#  'MNIST/train\\000793-num9.png',
#  'MNIST/train\\000794-num6.png',
#  'MNIST/train\\000795-num7.png',
#  'MNIST/train\\000796-num8.png',
#  'MNIST/train\\000797-num4.png',
#  'MNIST/train\\000798-num7.png',
#  'MNIST/train\\000799-num5.png',
#  'MNIST/train\\000800-num9.png',
#  'MNIST/train\\000801-num2.png',
#  'MNIST/train\\000802-num6.png',
#  'MNIST/train\\000803-num7.png',
#  'MNIST/train\\000804-num4.png',
#  'MNIST/train\\000805-num5.png',
#  'MNIST/train\\000806-num9.png',
#  'MNIST/train\\000807-num2.png',
#  'MNIST/train\\000808-num3.png',
#  'MNIST/train\\000809-num1.png',
#  'MNIST/train\\000810-num6.png',
#  'MNIST/train\\000811-num3.png',
#  'MNIST/train\\000812-num9.png',
#  'MNIST/train\\000813-num2.png',
#  'MNIST/train\\000814-num2.png',
#  'MNIST/train\\000815-num5.png',
#  'MNIST/train\\000816-num6.png',
#  'MNIST/train\\000817-num8.png',
#  'MNIST/train\\000818-num0.png',
#  'MNIST/train\\000819-num7.png',
#  'MNIST/train\\000820-num7.png',
#  'MNIST/train\\000821-num1.png',
#  'MNIST/train\\000822-num9.png',
#  'MNIST/train\\000823-num8.png',
#  'MNIST/train\\000824-num7.png',
#  'MNIST/train\\000825-num0.png',
#  'MNIST/train\\000826-num9.png',
#  'MNIST/train\\000827-num9.png',
#  'MNIST/train\\000828-num4.png',
#  'MNIST/train\\000829-num6.png',
#  'MNIST/train\\000830-num2.png',
#  'MNIST/train\\000831-num8.png',
#  'MNIST/train\\000832-num5.png',
#  'MNIST/train\\000833-num1.png',
#  'MNIST/train\\000834-num4.png',
#  'MNIST/train\\000835-num1.png',
#  'MNIST/train\\000836-num5.png',
#  'MNIST/train\\000837-num5.png',
#  'MNIST/train\\000838-num1.png',
#  'MNIST/train\\000839-num7.png',
#  'MNIST/train\\000840-num3.png',
#  'MNIST/train\\000841-num6.png',
#  'MNIST/train\\000842-num4.png',
#  'MNIST/train\\000843-num3.png',
#  'MNIST/train\\000844-num2.png',
#  'MNIST/train\\000845-num5.png',
#  'MNIST/train\\000846-num6.png',
#  'MNIST/train\\000847-num4.png',
#  'MNIST/train\\000848-num4.png',
#  'MNIST/train\\000849-num0.png',
#  'MNIST/train\\000850-num4.png',
#  'MNIST/train\\000851-num4.png',
#  'MNIST/train\\000852-num6.png',
#  'MNIST/train\\000853-num7.png',
#  'MNIST/train\\000854-num2.png',
#  'MNIST/train\\000855-num4.png',
#  'MNIST/train\\000856-num3.png',
#  'MNIST/train\\000857-num3.png',
#  'MNIST/train\\000858-num8.png',
#  'MNIST/train\\000859-num0.png',
#  'MNIST/train\\000860-num0.png',
#  'MNIST/train\\000861-num3.png',
#  'MNIST/train\\000862-num2.png',
#  'MNIST/train\\000863-num2.png',
#  'MNIST/train\\000864-num9.png',
#  'MNIST/train\\000865-num8.png',
#  'MNIST/train\\000866-num2.png',
#  'MNIST/train\\000867-num3.png',
#  'MNIST/train\\000868-num7.png',
#  'MNIST/train\\000869-num0.png',
#  'MNIST/train\\000870-num1.png',
#  'MNIST/train\\000871-num1.png',
#  'MNIST/train\\000872-num0.png',
#  'MNIST/train\\000873-num2.png',
#  'MNIST/train\\000874-num3.png',
#  'MNIST/train\\000875-num3.png',
#  'MNIST/train\\000876-num8.png',
#  'MNIST/train\\000877-num4.png',
#  'MNIST/train\\000878-num3.png',
#  'MNIST/train\\000879-num5.png',
#  'MNIST/train\\000880-num7.png',
#  'MNIST/train\\000881-num6.png',
#  'MNIST/train\\000882-num4.png',
#  'MNIST/train\\000883-num7.png',
#  'MNIST/train\\000884-num7.png',
#  'MNIST/train\\000885-num8.png',
#  'MNIST/train\\000886-num5.png',
#  'MNIST/train\\000887-num9.png',
#  'MNIST/train\\000888-num7.png',
#  'MNIST/train\\000889-num0.png',
#  'MNIST/train\\000890-num3.png',
#  'MNIST/train\\000891-num1.png',
#  'MNIST/train\\000892-num6.png',
#  'MNIST/train\\000893-num2.png',
#  'MNIST/train\\000894-num4.png',
#  'MNIST/train\\000895-num3.png',
#  'MNIST/train\\000896-num4.png',
#  'MNIST/train\\000897-num4.png',
#  'MNIST/train\\000898-num7.png',
#  'MNIST/train\\000899-num5.png',
#  'MNIST/train\\000900-num9.png',
#  'MNIST/train\\000901-num6.png',
#  'MNIST/train\\000902-num9.png',
#  'MNIST/train\\000903-num0.png',
#  'MNIST/train\\000904-num7.png',
#  'MNIST/train\\000905-num1.png',
#  'MNIST/train\\000906-num4.png',
#  'MNIST/train\\000907-num2.png',
#  'MNIST/train\\000908-num7.png',
#  'MNIST/train\\000909-num3.png',
#  'MNIST/train\\000910-num6.png',
#  'MNIST/train\\000911-num7.png',
#  'MNIST/train\\000912-num5.png',
#  'MNIST/train\\000913-num8.png',
#  'MNIST/train\\000914-num4.png',
#  'MNIST/train\\000915-num5.png',
#  'MNIST/train\\000916-num5.png',
#  'MNIST/train\\000917-num2.png',
#  'MNIST/train\\000918-num7.png',
#  'MNIST/train\\000919-num1.png',
#  'MNIST/train\\000920-num1.png',
#  'MNIST/train\\000921-num5.png',
#  'MNIST/train\\000922-num6.png',
#  'MNIST/train\\000923-num8.png',
#  'MNIST/train\\000924-num5.png',
#  'MNIST/train\\000925-num8.png',
#  'MNIST/train\\000926-num4.png',
#  'MNIST/train\\000927-num0.png',
#  'MNIST/train\\000928-num7.png',
#  'MNIST/train\\000929-num9.png',
#  'MNIST/train\\000930-num9.png',
#  'MNIST/train\\000931-num2.png',
#  'MNIST/train\\000932-num9.png',
#  'MNIST/train\\000933-num7.png',
#  'MNIST/train\\000934-num7.png',
#  'MNIST/train\\000935-num8.png',
#  'MNIST/train\\000936-num7.png',
#  'MNIST/train\\000937-num4.png',
#  'MNIST/train\\000938-num2.png',
#  'MNIST/train\\000939-num6.png',
#  'MNIST/train\\000940-num9.png',
#  'MNIST/train\\000941-num1.png',
#  'MNIST/train\\000942-num7.png',
#  'MNIST/train\\000943-num0.png',
#  'MNIST/train\\000944-num6.png',
#  'MNIST/train\\000945-num4.png',
#  'MNIST/train\\000946-num2.png',
#  'MNIST/train\\000947-num5.png',
#  'MNIST/train\\000948-num7.png',
#  'MNIST/train\\000949-num0.png',
#  'MNIST/train\\000950-num7.png',
#  'MNIST/train\\000951-num1.png',
#  'MNIST/train\\000952-num0.png',
#  'MNIST/train\\000953-num3.png',
#  'MNIST/train\\000954-num7.png',
#  'MNIST/train\\000955-num6.png',
#  'MNIST/train\\000956-num5.png',
#  'MNIST/train\\000957-num0.png',
#  'MNIST/train\\000958-num6.png',
#  'MNIST/train\\000959-num1.png',
#  'MNIST/train\\000960-num5.png',
#  'MNIST/train\\000961-num1.png',
#  'MNIST/train\\000962-num7.png',
#  'MNIST/train\\000963-num8.png',
#  'MNIST/train\\000964-num5.png',
#  'MNIST/train\\000965-num0.png',
#  'MNIST/train\\000966-num3.png',
#  'MNIST/train\\000967-num4.png',
#  'MNIST/train\\000968-num7.png',
#  'MNIST/train\\000969-num7.png',
#  'MNIST/train\\000970-num5.png',
#  'MNIST/train\\000971-num7.png',
#  'MNIST/train\\000972-num8.png',
#  'MNIST/train\\000973-num6.png',
#  'MNIST/train\\000974-num9.png',
#  'MNIST/train\\000975-num3.png',
#  'MNIST/train\\000976-num8.png',
#  'MNIST/train\\000977-num6.png',
#  'MNIST/train\\000978-num1.png',
#  'MNIST/train\\000979-num0.png',
#  'MNIST/train\\000980-num9.png',
#  'MNIST/train\\000981-num7.png',
#  'MNIST/train\\000982-num1.png',
#  'MNIST/train\\000983-num3.png',
#  'MNIST/train\\000984-num0.png',
#  'MNIST/train\\000985-num5.png',
#  'MNIST/train\\000986-num6.png',
#  'MNIST/train\\000987-num4.png',
#  'MNIST/train\\000988-num4.png',
#  'MNIST/train\\000989-num2.png',
#  'MNIST/train\\000990-num4.png',
#  'MNIST/train\\000991-num4.png',
#  'MNIST/train\\000992-num3.png',
#  'MNIST/train\\000993-num1.png',
#  'MNIST/train\\000994-num7.png',
#  'MNIST/train\\000995-num7.png',
#  'MNIST/train\\000996-num6.png',
#  'MNIST/train\\000997-num0.png',
#  'MNIST/train\\000998-num3.png',
#  'MNIST/train\\000999-num6.png',
#  ...]

# %%
image_train = np.empty((0,784), int)
label_train = np.empty((0,1), int)

num_train = 6000
i = 0
for image_path in glob.glob("MNIST/train/*.png"):
    image = imageio.imread(image_path)
    image = np.array(image)
    image = image.reshape(1, -1)
    image_train = np.vstack((image_train, image))
    
    label = int(image_path[::-1][4])
    label_train = np.vstack((label_train, label))
    
    i += 1
    if i >= num_train:
        break

print(image_train.shape)
print(label_train.shape)
# Out:
# (6000, 784)
# (6000, 1)

# %%
X_Train = image_train/255
Y_Train = create_onehot_target(label_train)

# %%
image_test = np.empty((0,784), int)
label_test = np.empty((0,1), int)

num_test = 1000
i = 0
for image_path in glob.glob("MNIST/test/*.png"):
    image = imageio.imread(image_path)
    image = np.array(image)
    image = image.reshape(1, -1)
    image_test = np.vstack((image_test, image))
    
    label = int(image_path[::-1][4])
    label_test = np.vstack((label_test, label))
    
    i += 1
    if i >= num_test:
        break

print(image_test.shape)
print(label_test.shape)
# Out:
# (1000, 784)
# (1000, 1)

# %%
X_Test = image_test/255
Y_Test = create_onehot_target(label_test)

# %% [markdown]
# # 4. Create Model

# %%
HL = [10, 10]

# %%
AF = ['ReLU', 'softmax']

# %% [markdown]
# # ---------- Mini-Batch (Batch Size = 64) ----------

# %%
start_minibatch = time.time()

# %%
W, B, error_list = NNC_find_WB(X_Train, Y_Train, HL, AF, epoch = 10000, lr = 0.1)

# %%
stop_minibatch = time.time()

# %%
process_time_minibatch = stop_minibatch - start_minibatch

# %%
process_time_minibatch
# Out:
# 5.6224517822265625

# %%
plt.plot(error_list)

# %% [markdown]
# # ---------- Batch (Batch Size = N) ----------

# %%
start_batch = time.time()

# %%
X_Train.shape[0]
# Out:
# 6000

# %%
W, B, error_list = NNC_find_WB(X_Train, Y_Train, HL, AF, epoch = 10000, lr = 0.1, batch_size = X_Train.shape[0])

# %%
stop_batch = time.time()

# %%
process_time_batch = stop_batch - start_batch

# %%
process_time_batch
# Out:
# 146.04287433624268

# %% [markdown]
# # ----- Mini-Batch is faster than Batch -----

# %%
process_time_batch/process_time_minibatch #เร็วต่างกันกี่เท่า
# Out:
# 25.974944738149063

# %% [markdown]
# # ----------------------------------------

# %%
plt.plot(error_list)

# %%
Zhat_Train, Yhat_Train = NN_forward(X_Train, W, B, AF)

# %%
error_Train = find_error(Y_Train, Yhat_Train[-1], 'Multiclass')

# %%
error_Train
# Out:
# 1.3166666666666667

# %% [markdown]
# # 5. Make Prediction

# %%
Zhat_Test, Yhat_Test = NN_forward(X_Test, W, B, AF)

# %%
error_Test = find_error(Y_Test, Yhat_Test[-1], 'Multiclass')

# %%
error_Test
# Out:
# 11.3

# %%
num_test = 100

for i, image_path in enumerate(glob.glob("MNIST/test/*.png")):
    image = imageio.imread(image_path)
    image = np.array(image)
    
    label = int(image_path[::-1][4])
    
    predicted = np.argmax(Yhat_Test[-1], axis=1)[i]
    
    plt.title('Predicted: {}, Actual: {}'.format(predicted, label))
    plt.imshow(image, cmap='gray')
    plt.show()
    
    if i >= num_test - 1:
        break
