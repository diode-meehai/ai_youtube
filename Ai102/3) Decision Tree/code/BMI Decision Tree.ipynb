# %% [markdown]
# # 1. Import Library

# %%
#!pip uninstall graphviz
#pip install graphviz
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/Diode/Anaconda3/envs/TF2_GPU/Library/bin/graphviz/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from graphviz import Graph
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Diode\Anaconda3\envs\TF2_GPU\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.2/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# # 2. Write Function

# %% [markdown]
# ### 2.1 หาคำถามที่แบ่งต้นไม้ได้ดีที่สุด

# %%
def DT_find_best_question(X, Y, Feature_Name, All_Class):
    max_Gain = -np.inf
    isComplete = False
    Gini_Parent = DT_compute_Gini(Y, All_Class)
    Question_Dict = DT_create_Question(X, Feature_Name)
    for d, fn in enumerate(Feature_Name):
        N = X.shape[0]
        if fn in Question_Dict:
            unique_value = Question_Dict[fn]['unique_value']
            check_type = Question_Dict[fn]['type_of_feature']
            for i, uv in enumerate(unique_value):                
                filter_true, filter_false = DT_find_filter(X, check_type, d, uv)
                X_True = X[filter_true]; Y_True = Y[filter_true];
                X_False = X[filter_false]; Y_False = Y[filter_false];
                weight_true, weight_false = DT_compute_weight_true_false(filter_true, filter_false, N)
                Gini_True, Gini_False = DT_compute_Gini_True_False(Y_True, Y_False, All_Class)
                Gini_Children = DT_compute_Gini_Children(weight_true, Gini_True, weight_false, Gini_False)
                Gain = DT_compute_Gain(Gini_Parent, Gini_Children)
                if Gain >= max_Gain:
                    max_Gain = Gain
                    best = {}
                    best['fn'] = fn
                    best['findex'] = d
                    best['uv'] = uv
                    best['X_True'] = X_True
                    best['Y_True'] = Y_True
                    best['X_False'] = X_False
                    best['Y_False'] = Y_False
                if max_Gain == Gini_Parent:
                    isComplete = True
                    return best, isComplete
    return best, isComplete

# %%
def DT_create_Question(X, Feature_Name):
    Question_Dict = {}
    for d, fn in enumerate(Feature_Name):
        unique_value = np.unique(X[:, d])
        check_type = type(unique_value[0])
        if check_type == str:
            if len(unique_value) >= 2:
                if len(unique_value) == 2:
                    unique_value = unique_value[:1]
                q = {}
                q['type_of_feature'] = 'discrete'
                q['unique_value'] = unique_value
                Question_Dict[fn] = q
        if (check_type == int) or (check_type == float):
            unique_value = unique_value[1:-1]
            if len(unique_value) != 0:            
                q = {}
                q['type_of_feature'] = 'continuous'
                q['unique_value'] = unique_value
                Question_Dict[fn] = q
    return Question_Dict

# %%
def DT_compute_Gini(Y, All_Class):
    n_class = len(All_Class)
    N = Y.shape[0]
    if N == 0:
        Gini = 0
    elif N != 0 :
        p = np.zeros([1, n_class])
        for c, _class in enumerate(All_Class):
            p[0, c] = (Y == _class).sum()/N
        Gini = 1 - (p**2).sum()
    return Gini

# %%
def DT_find_filter(X, check_type, d, uv):
    if check_type == 'discrete':
        filter_true = np.argwhere(X[:, d] == uv).ravel()
        filter_false = np.argwhere(X[:, d] != uv).ravel()
    elif check_type == 'continuous':
        filter_true = np.argwhere(X[:, d] >= uv).ravel()
        filter_false = np.argwhere(X[:, d] < uv).ravel()
    return filter_true, filter_false

# %%
def DT_compute_weight_true_false(filter_true, filter_false, N):
    count_true = len(filter_true)
    count_false = N - count_true
    weight_true = count_true/N
    weight_false = count_false/N
    return weight_true, weight_false

# %%
def DT_compute_Gini_True_False(Y_True, Y_False, All_Class):
    Gini_True = DT_compute_Gini(Y_True, All_Class)
    Gini_False = DT_compute_Gini(Y_False, All_Class)
    return Gini_True, Gini_False

# %%
def DT_compute_Gini_Children(weight_true, Gini_True, weight_false, Gini_False):
    Gini_Children = weight_true*Gini_True + weight_false*Gini_False
    return Gini_Children

# %%
def DT_compute_Gain(Gini_Parent, Gini_Children):
    Gain = Gini_Parent - Gini_Children
    return Gain

# %% [markdown]
# ### 2.2 ปลูกต้นไม้

# %%
def DT_grow_tree(best, Y_True, Y_False, All_Class):
    fn = best['fn']
    findex = best['findex']
    uv = best['uv']
    if type(uv) == str:
        type_of_feature = 'discrete'
    elif (type(uv) == float) or (type(uv) == int):
        type_of_feature = 'continuous'
    
    Question = {} 
    Question['fn'] = fn
    Question['findex'] = findex; Question['uv'] = uv
    Question['type_of_feature'] = type_of_feature
    
    Leaf_Node_True, Vote_True, Max_Vote_True, Max_Class_True = DT_Leaf(Y_True, All_Class)
    True_Branch = {}
    True_Branch['Leaf_Node'] = Leaf_Node_True
    True_Branch['Vote'] = Vote_True
    True_Branch['Predict'] = Max_Class_True
    True_Branch['Percent'] = Max_Vote_True
    
    Leaf_Node_False, Vote_False, Max_Vote_False, Max_Class_False = DT_Leaf(Y_False, All_Class)
    False_Branch = {} 
    False_Branch['Leaf_Node'] = Leaf_Node_False
    False_Branch['Vote'] = Vote_False
    False_Branch['Predict'] = Max_Class_False
    False_Branch['Percent'] = Max_Vote_False
    
    Decision_Node = {}
    Decision_Node['Question'] = Question
    Decision_Node['True_Branch'] = True_Branch
    Decision_Node['False_Branch'] = False_Branch
    
    return Decision_Node, Max_Vote_True, Max_Vote_False

# %%
def DT_Leaf(Y, All_Class):
    N = Y.shape[0]
    leaf_node = {}
    vote = {}
    max_vote = -np.inf
    for c, _class in enumerate(All_Class):
        length = (Y == _class).sum()
        percent_vote = 100*length/N
        if max_vote < percent_vote:
            max_vote = percent_vote
            max_class = _class
        leaf_node[_class] = length
        vote[_class] = percent_vote
    return leaf_node, vote, max_vote, max_class

# %% [markdown]
# ### 2.3 เรียนรู้

# %%
def DT_fit(X_Train, Y_Train, Feature_Name, All_Class, max_depth=np.inf, depth=1, max_majority=np.inf, min_leaf=-np.inf):
    best, isComplete = DT_find_best_question(X_Train, Y_Train, Feature_Name, All_Class)
    Y_True = best['Y_True']
    Y_False = best['Y_False']
    Decision_Node, Max_Vote_True, Max_Vote_False = DT_grow_tree(best, Y_True, Y_False, All_Class)

    if max_depth == depth:
        return Decision_Node
    if isComplete == True:
        return Decision_Node
    
    if Max_Vote_True < max_majority:
        if len(Y_True) > min_leaf:
            X_True = best['X_True']
            Decision_Node['True_Branch']['Decision_Node']  = DT_fit(X_True, Y_True, Feature_Name, All_Class, max_depth=max_depth, depth=depth+1, max_majority=max_majority, min_leaf=min_leaf)
    if Max_Vote_False < max_majority:
        if len(Y_False) > min_leaf:
            X_False = best['X_False']
            Decision_Node['False_Branch']['Decision_Node'] = DT_fit(X_False ,Y_False, Feature_Name, All_Class, max_depth=max_depth, depth=depth+1, max_majority=max_majority, min_leaf=min_leaf)
    return Decision_Node

# %% [markdown]
# ### 2.4 พยากรณ์

# %%
def DT_recursive_predict(x_test, tree):
    fn = tree['Question']['fn']
    findex = tree['Question']['findex']
    value = tree['Question']['uv']
    type_of_feature = tree['Question']['type_of_feature']

    if type_of_feature == 'discrete':
        if x_test[findex] == value:
            if 'Decision_Node' not in tree['True_Branch']:
                predict = tree['True_Branch']['Predict']
                percent = tree['True_Branch']['Percent']
                yhat = np.array([predict, percent])
                return yhat
            elif 'Decision_Node' in tree['True_Branch']:
                tree = tree['True_Branch']['Decision_Node']
                yhat = DT_recursive_predict(x_test, tree)
                return yhat
        elif x_test[findex] != value:
            if 'Decision_Node' not in tree['False_Branch']:
                predict = tree['False_Branch']['Predict']
                percent = tree['False_Branch']['Percent']
                yhat = np.array([predict, percent])
                return yhat
            elif 'Decision_Node' in tree['False_Branch']:
                tree = tree['False_Branch']['Decision_Node']
                yhat = DT_recursive_predict(x_test, tree)
                return yhat
                
    if type_of_feature == 'continuous':
        if x_test[findex] >= value:
            if 'Decision_Node' not in tree['True_Branch']:
                predict = tree['True_Branch']['Predict']
                percent = tree['True_Branch']['Percent']
                yhat = np.array([predict, percent])
                return yhat
            elif 'Decision_Node' in tree['True_Branch']:
                tree = tree['True_Branch']['Decision_Node']
                yhat = DT_recursive_predict(x_test, tree)
                return yhat
        elif x_test[findex] < value:
            if 'Decision_Node' not in tree['False_Branch']:
                predict = tree['False_Branch']['Predict']
                percent = tree['False_Branch']['Percent']
                yhat = np.array([predict, percent])
                return yhat
            elif 'Decision_Node' in tree['False_Branch']:
                tree = tree['False_Branch']['Decision_Node']
                yhat = DT_recursive_predict(x_test, tree)
                return yhat

# %%
def DT_predict(X_Test, tree):
    Yhat = []
    for x_test in X_Test:
        yhat = DT_recursive_predict(x_test, tree)
        Yhat.append(yhat)
    return np.array(Yhat)

# %%
def find_error_classification(Y, Yhat):
    N = Y.shape[0]
    error = (100/N)*(Y != Yhat).sum()
    return error

# %% [markdown]
# ### 2.5 วาดต้นไม้

# %%
def DT_print_tree(node, prev_id, spacing=""):
    global curr_id  
    curr_id += 1
    
    if 'Question' not in node:
        node_predictions = "{} : {}".format(node['Predict'], round(node['Percent'], 2))
        g.node(str(prev_id), label=str(node_predictions))
        return
    
    node_question = "{} {} {}".format(node['Question']['fn'], '=' if isinstance(node['Question']['uv'], str) else '>=', node['Question']['uv'] if isinstance(node['Question']['uv'], str) else round(node['Question']['uv'], 6))
    g.node(str(prev_id), label=str(node_question))

    true_node = node['True_Branch']['Decision_Node'] if 'Decision_Node' in node['True_Branch'] else node['True_Branch']
    V.append((prev_id, curr_id))
    DT_print_tree(true_node, curr_id, spacing + "  ")
    
    false_node = node['False_Branch']['Decision_Node'] if 'Decision_Node' in node['False_Branch'] else node['False_Branch']
    V.append((prev_id, curr_id))
    DT_print_tree(false_node, curr_id, spacing + "  ")

# %% [markdown]
# # 3. Read Data & Prepare Data

# %%
Data = pd.read_excel('BMI_Dataset_Classification.xlsx', usecols = 'A:C')

# %%
Data
# Out:
#      Weight  Height   Target
# 0     66.17  185.21   normal
# 1     71.27  168.91  fat lv3
# 2     73.17  179.83   normal
# 3     81.74  171.76  fat lv2
# 4     92.97  172.89  fat lv3
# ..      ...     ...      ...
# 995   63.24  141.45  fat lv3
# 996   47.55  166.64     thin
# 997   68.10  168.52  fat lv1
# 998   74.39  169.24  fat lv2
# 999   65.95  174.37   normal
#
# [1000 rows x 3 columns]

# %%
DataMatrix = Data.values

# %%
DataMatrix = np.array(DataMatrix, dtype='object')

# %%
DataMatrix.shape
# Out:
# (1000, 3)

# %%
D = DataMatrix.shape[1] - 1

# %%
X = DataMatrix[:, :D]
Y = DataMatrix[:, D:]

# %%
start_train = -900
end_train = -150
# end_test = -150

# %%
X_Train = X[start_train:end_train, :]
Y_Train = Y[start_train:end_train, :]

X_Test = X[end_train:, :]
Y_Test = Y[end_train:, :]

# X_Test = X[end_train:end_test, :]
# Y_Test = Y[end_train:end_test, :]

# %%
X_Train
# Out:
# array([[53.18, 157.29],
#        [61.63, 177.32],
#        [72.95, 173.86],
#        ...,
#        [69.19, 151.4],
#        [64.51, 179.16],
#        [92.76, 165.4]], dtype=object)

# %%
Y_Train
# Out:
# array([['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['thin'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['thin'],
#        ['thin'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['thin'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['thin'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['thin'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['thin'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['thin'],
#        ['normal'],
#        ['thin'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['thin'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['thin'],
#        ['thin'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['thin'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['thin'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['thin'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['thin'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['thin'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['thin'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['thin'],
#        ['fat lv2'],
#        ['normal'],
#        ['thin'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['thin'],
#        ['fat lv3'],
#        ['thin'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['thin'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['thin'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['thin'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['thin'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['thin'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['thin'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['thin'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['thin'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['thin'],
#        ['normal'],
#        ['thin'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['thin'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['thin'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['thin'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['thin'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['thin'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['thin'],
#        ['thin'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['thin'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['thin'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['thin'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['thin'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['thin'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['thin'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['thin'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['thin'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['thin'],
#        ['normal'],
#        ['thin'],
#        ['fat lv2'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3']], dtype=object)

# %%
Y_Test
# Out:
# array([['fat lv2'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['thin'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['thin'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv1'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['thin'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv3'],
#        ['thin'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv3'],
#        ['normal'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['fat lv1'],
#        ['thin'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['fat lv2'],
#        ['thin'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['normal'],
#        ['fat lv2'],
#        ['fat lv3'],
#        ['fat lv2'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['fat lv1'],
#        ['normal'],
#        ['fat lv3'],
#        ['fat lv3'],
#        ['thin'],
#        ['fat lv1'],
#        ['fat lv2'],
#        ['normal']], dtype=object)

# %% [markdown]
# # 4. Create Model

# %%
Feature_Name = np.array(Data.columns[:-1])
All_Class, Count_All_Class = np.unique(Y_Train[:, :], return_counts = True)

# %%
All_Class
# Out:
# array(['fat lv1', 'fat lv2', 'fat lv3', 'normal', 'thin'], dtype=object)

# %%
Count_All_Class
# Out:
# array([145, 191, 131, 224,  59], dtype=int64)

# %%
tree = DT_fit(X_Train, Y_Train, Feature_Name, All_Class, max_depth = 5, max_majority = 65, min_leaf = 20)
tree
# Out:
# {'Question': {'fn': 'Weight',
#   'findex': 0,
#   'uv': 69.9,
#   'type_of_feature': 'continuous'},
#  'True_Branch': {'Leaf_Node': {'fat lv1': 70,
#    'fat lv2': 161,
#    'fat lv3': 102,
#    'normal': 26,
#    'thin': 0},
#   'Vote': {'fat lv1': 19.498607242339833,
#    'fat lv2': 44.84679665738162,
#    'fat lv3': 28.41225626740947,
#    'normal': 7.242339832869081,
#    'thin': 0.0},
#   'Predict': 'fat lv2',
#   'Percent': 44.84679665738162,
#   'Decision_Node': {'Question': {'fn': 'Height',
#     'findex': 1,
#     'uv': 169.7,
#     'type_of_feature': 'continuous'},
#    'True_Branch': {'Leaf_Node': {'fat lv1': 68,
#      'fat lv2': 58,
#      'fat lv3': 32,
#      'normal': 26,
#      'thin': 0},
#     'Vote': {'fat lv1': 36.95652173913044,
#      'fat lv2': 31.52173913043478,
#      'fat lv3': 17.391304347826086,
#      'normal': 14.130434782608695,
#      'thin': 0.0},
#     'Predict': 'fat lv1',
#     'Percent': 36.95652173913044,
#     'Decision_Node': {'Question': {'fn': 'Weight',
#       'findex': 0,
#       'uv': 77.69,
#       'type_of_feature': 'continuous'},
#      'True_Branch': {'Leaf_Node': {'fat lv1': 7,
#        'fat lv2': 51,
#        'fat lv3': 15,
#        'normal': 2,
#        'thin': 0},
#       'Vote': {'fat lv1': 9.333333333333334,
#        'fat lv2': 68.0,
#        'fat lv3': 20.0,
#        'normal': 2.6666666666666665,
#        'thin': 0.0},
#       'Predict': 'fat lv2',
#       'Percent': 68.0},
#      'False_Branch': {'Leaf_Node': {'fat lv1': 61,
#        'fat lv2': 7,
#        'fat lv3': 17,
#        'normal': 24,
#        'thin': 0},
#       'Vote': {'fat lv1': 55.96330275229358,
#        'fat lv2': 6.422018348623853,
#        'fat lv3': 15.596330275229358,
#        'normal': 22.01834862385321,
#        'thin': 0.0},
#       'Predict': 'fat lv1',
#       'Percent': 55.96330275229358,
#       'Decision_Node': {'Question': {'fn': 'Height',
#         'findex': 1,
#         'uv': 179.2,
#         'type_of_feature': 'continuous'},
#        'True_Branch': {'Leaf_Node': {'fat lv1': 1,
#          'fat lv2': 0,
#          'fat lv3': 1,
#          'normal': 18,
#          'thin': 0},
#         'Vote': {'fat lv1': 5.0,
#          'fat lv2': 0.0,
#          'fat lv3': 5.0,
#          'normal': 90.0,
#          'thin': 0.0},
#         'Predict': 'normal',
#         'Percent': 90.0},
#        'False_Branch': {'Leaf_Node': {'fat lv1': 60,
#          'fat lv2': 7,
#          'fat lv3': 16,
#          'normal': 6,
#          'thin': 0},
#         'Vote': {'fat lv1': 67.41573033707866,
#          'fat lv2': 7.865168539325842,
#          'fat lv3': 17.97752808988764,
#          'normal': 6.741573033707865,
#          'thin': 0.0},
#         'Predict': 'fat lv1',
#         'Percent': 67.41573033707866}}}}},
#    'False_Branch': {'Leaf_Node': {'fat lv1': 2,
#      'fat lv2': 103,
#      'fat lv3': 70,
#      'normal': 0,
#      'thin': 0},
#     'Vote': {'fat lv1': 1.1428571428571428,
#      'fat lv2': 58.857142857142854,
#      'fat lv3': 40.0,
#      'normal': 0.0,
#      'thin': 0.0},
#     'Predict': 'fat lv2',
#     'Percent': 58.857142857142854,
#     'Decision_Node': {'Question': {'fn': 'Weight',
#       'findex': 0,
#       'uv': 79.59,
#       'type_of_feature': 'continuous'},
#      'True_Branch': {'Leaf_Node': {'fat lv1': 0,
#        'fat lv2': 13,
#        'fat lv3': 55,
#        'normal': 0,
#        'thin': 0},
#       'Vote': {'fat lv1': 0.0,
#        'fat lv2': 19.11764705882353,
#        'fat lv3': 80.88235294117646,
#        'normal': 0.0,
#        'thin': 0.0},
#       'Predict': 'fat lv3',
#       'Percent': 80.88235294117646},
#      'False_Branch': {'Leaf_Node': {'fat lv1': 2,
#        'fat lv2': 90,
#        'fat lv3': 15,
#        'normal': 0,
#        'thin': 0},
#       'Vote': {'fat lv1': 1.8691588785046729,
#        'fat lv2': 84.11214953271028,
#        'fat lv3': 14.018691588785046,
#        'normal': 0.0,
#        'thin': 0.0},
#       'Predict': 'fat lv2',
#       'Percent': 84.11214953271028}}}}},
#  'False_Branch': {'Leaf_Node': {'fat lv1': 75,
#    'fat lv2': 30,
#    'fat lv3': 29,
#    'normal': 198,
#    'thin': 59},
#   'Vote': {'fat lv1': 19.18158567774936,
#    'fat lv2': 7.672634271099744,
#    'fat lv3': 7.41687979539642,
#    'normal': 50.63938618925831,
#    'thin': 15.089514066496164},
#   'Predict': 'normal',
#   'Percent': 50.63938618925831,
#   'Decision_Node': {'Question': {'fn': 'Weight',
#     'findex': 0,
#     'uv': 54.43,
#     'type_of_feature': 'continuous'},
#    'True_Branch': {'Leaf_Node': {'fat lv1': 75,
#      'fat lv2': 30,
#      'fat lv3': 29,
#      'normal': 189,
#      'thin': 20},
#     'Vote': {'fat lv1': 21.865889212827987,
#      'fat lv2': 8.746355685131196,
#      'fat lv3': 8.454810495626822,
#      'normal': 55.10204081632653,
#      'thin': 5.830903790087463},
#     'Predict': 'normal',
#     'Percent': 55.10204081632653,
#     'Decision_Node': {'Question': {'fn': 'Height',
#       'findex': 1,
#       'uv': 169.31,
#       'type_of_feature': 'continuous'},
#      'True_Branch': {'Leaf_Node': {'fat lv1': 10,
#        'fat lv2': 0,
#        'fat lv3': 2,
#        'normal': 141,
#        'thin': 20},
#       'Vote': {'fat lv1': 5.780346820809249,
#        'fat lv2': 0.0,
#        'fat lv3': 1.1560693641618498,
#        'normal': 81.5028901734104,
#        'thin': 11.560693641618498},
#       'Predict': 'normal',
#       'Percent': 81.5028901734104},
#      'False_Branch': {'Leaf_Node': {'fat lv1': 65,
#        'fat lv2': 30,
#        'fat lv3': 27,
#        'normal': 48,
#        'thin': 0},
#       'Vote': {'fat lv1': 38.23529411764706,
#        'fat lv2': 17.647058823529413,
#        'fat lv3': 15.882352941176471,
#        'normal': 28.235294117647058,
#        'thin': 0.0},
#       'Predict': 'fat lv1',
#       'Percent': 38.23529411764706,
#       'Decision_Node': {'Question': {'fn': 'Weight',
#         'findex': 0,
#         'uv': 61.74,
#         'type_of_feature': 'continuous'},
#        'True_Branch': {'Leaf_Node': {'fat lv1': 54,
#          'fat lv2': 28,
#          'fat lv3': 25,
#          'normal': 4,
#          'thin': 0},
#         'Vote': {'fat lv1': 48.648648648648646,
#          'fat lv2': 25.225225225225227,
#          'fat lv3': 22.52252252252252,
#          'normal': 3.6036036036036037,
#          'thin': 0.0},
#         'Predict': 'fat lv1',
#         'Percent': 48.648648648648646,
#         'Decision_Node': {'Question': {'fn': 'Height',
#           'findex': 1,
#           'uv': 162.63,
#           'type_of_feature': 'continuous'},
#          'True_Branch': {'Leaf_Node': {'fat lv1': 47,
#            'fat lv2': 1,
#            'fat lv3': 12,
#            'normal': 4,
#            'thin': 0},
#           'Vote': {'fat lv1': 73.4375,
#            'fat lv2': 1.5625,
#            'fat lv3': 18.75,
#            'normal': 6.25,
#            'thin': 0.0},
#           'Predict': 'fat lv1',
#           'Percent': 73.4375},
#          'False_Branch': {'Leaf_Node': {'fat lv1': 7,
#            'fat lv2': 27,
#            'fat lv3': 13,
#            'normal': 0,
#            'thin': 0},
#           'Vote': {'fat lv1': 14.893617021276595,
#            'fat lv2': 57.4468085106383,
#            'fat lv3': 27.659574468085108,
#            'normal': 0.0,
#            'thin': 0.0},
#           'Predict': 'fat lv2',
#           'Percent': 57.4468085106383}}},
#        'False_Branch': {'Leaf_Node': {'fat lv1': 11,
#          'fat lv2': 2,
#          'fat lv3': 2,
#          'normal': 44,
#          'thin': 0},
#         'Vote': {'fat lv1': 18.64406779661017,
#          'fat lv2': 3.389830508474576,
#          'fat lv3': 3.389830508474576,
#          'normal': 74.57627118644068,
#          'thin': 0.0},
#         'Predict': 'normal',
#         'Percent': 74.57627118644068}}}}},
#    'False_Branch': {'Leaf_Node': {'fat lv1': 0,
#      'fat lv2': 0,
#      'fat lv3': 0,
#      'normal': 9,
#      'thin': 39},
#     'Vote': {'fat lv1': 0.0,
#      'fat lv2': 0.0,
#      'fat lv3': 0.0,
#      'normal': 18.75,
#      'thin': 81.25},
#     'Predict': 'thin',
#     'Percent': 81.25}}}}

# %%
type(tree)
# Out:
# dict

# %%
g = Graph('G')
g.attr('node', shape='box', style='filled', color='darkseagreen1')
curr_id = 1   
V = []
DT_print_tree(tree, curr_id)

for v in V:
    g.edge(str(v[0]), str(v[1]), 'True' if v[1] - v[0] == 1 else 'False')
g

# %% [markdown]
# # 5. Making Prediction

# %%
X_Test
# Out:
# array([[75.86, 171.07],
#        [72.12, 164.26],
#        [79.4, 160.18],
#        [61.0, 150.86],
#        [72.51, 157.02],
#        [64.38, 184.22],
#        [52.62, 157.39],
#        [74.72, 172.37],
#        [62.66, 161.64],
#        [68.75, 168.31],
#        [73.8, 183.24],
#        [61.95, 165.24],
#        [56.53, 170.12],
#        [76.06, 169.59],
#        [69.3, 174.74],
#        [80.01, 155.61],
#        [59.72, 159.73],
#        [64.26, 178.87],
#        [80.31, 161.2],
#        [67.54, 176.67],
#        [68.97, 170.59],
#        [75.63, 171.97],
#        [60.3, 159.53],
#        [56.92, 167.21],
#        [72.87, 174.9],
#        [71.88, 170.55],
#        [71.78, 176.55],
#        [60.42, 167.97],
#        [77.21, 167.5],
#        [58.07, 176.81],
#        [61.81, 170.66],
#        [69.07, 170.12],
#        [79.26, 175.98],
#        [88.55, 168.18],
#        [67.81, 174.75],
#        [61.44, 170.4],
#        [71.99, 165.21],
#        [63.29, 156.73],
#        [68.88, 181.27],
#        [68.19, 174.19],
#        [78.49, 167.49],
#        [68.67, 149.29],
#        [51.09, 172.27],
#        [54.68, 164.67],
#        [74.83, 167.91],
#        [66.83, 167.46],
#        [66.83, 169.3],
#        [48.26, 171.93],
#        [84.25, 179.63],
#        [61.46, 176.09],
#        [75.83, 174.86],
#        [53.23, 160.54],
#        [63.61, 166.82],
#        [60.8, 177.56],
#        [60.79, 171.13],
#        [68.63, 173.97],
#        [72.5, 187.21],
#        [90.36, 158.53],
#        [66.96, 151.02],
#        [65.31, 179.31],
#        [64.71, 187.33],
#        [66.74, 159.02],
#        [54.81, 164.11],
#        [67.64, 186.3],
#        [70.09, 162.57],
#        [67.4, 179.87],
#        [78.78, 175.33],
#        [67.94, 158.21],
#        [70.85, 186.45],
#        [76.52, 156.77],
#        [70.58, 166.88],
#        [69.89, 175.56],
#        [73.22, 154.94],
#        [59.28, 161.18],
#        [64.49, 160.86],
#        [64.18, 173.84],
#        [79.54, 157.74],
#        [57.86, 156.34],
#        [81.11, 158.03],
#        [64.29, 182.29],
#        [69.91, 166.03],
#        [43.67, 177.61],
#        [70.14, 170.89],
#        [80.09, 181.59],
#        [75.71, 173.64],
#        [73.83, 186.04],
#        [70.58, 160.64],
#        [78.17, 170.78],
#        [88.95, 180.56],
#        [71.25, 188.24],
#        [73.48, 161.39],
#        [72.26, 168.69],
#        [75.1, 161.09],
#        [71.77, 185.37],
#        [74.3, 152.19],
#        [78.77, 172.05],
#        [58.7, 164.12],
#        [84.24, 168.02],
#        [73.42, 168.87],
#        [61.94, 168.68],
#        [63.52, 158.64],
#        [71.47, 162.71],
#        [66.13, 150.19],
#        [67.46, 173.53],
#        [74.64, 157.5],
#        [64.32, 183.19],
#        [70.49, 171.89],
#        [69.68, 172.9],
#        [70.15, 174.08],
#        [59.58, 168.88],
#        [81.13, 160.55],
#        [65.63, 162.28],
#        [88.68, 175.76],
#        [58.58, 158.33],
#        [63.26, 185.46],
#        [79.94, 168.28],
#        [60.42, 175.66],
#        [64.45, 171.01],
#        [74.51, 149.61],
#        [62.9, 159.95],
#        [75.53, 175.97],
#        [69.73, 180.21],
#        [87.47, 162.2],
#        [74.48, 174.23],
#        [70.95, 163.99],
#        [68.25, 160.27],
#        [67.86, 162.98],
#        [47.72, 163.66],
#        [69.24, 171.3],
#        [68.79, 155.13],
#        [61.83, 176.84],
#        [67.68, 156.61],
#        [73.11, 179.59],
#        [74.51, 165.36],
#        [80.6, 159.17],
#        [60.09, 150.72],
#        [53.02, 166.01],
#        [57.94, 165.24],
#        [59.87, 170.02],
#        [55.34, 169.93],
#        [65.89, 161.26],
#        [91.8, 169.54],
#        [67.59, 166.0],
#        [56.73, 161.24],
#        [69.19, 152.09],
#        [63.24, 141.45],
#        [47.55, 166.64],
#        [68.1, 168.52],
#        [74.39, 169.24],
#        [65.95, 174.37]], dtype=object)

# %%
Yhat_Test = DT_predict(X_Test, tree)

# %%
Yhat_Test
# Out:
# array([['fat lv1', '67.41573033707866'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '74.57627118644068'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '81.5028901734104'],
#        ['thin', '81.25'],
#        ['fat lv1', '67.41573033707866'],
#        ['fat lv2', '57.4468085106383'],
#        ['fat lv1', '73.4375'],
#        ['normal', '90.0'],
#        ['fat lv1', '73.4375'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '81.5028901734104'],
#        ['fat lv3', '80.88235294117646'],
#        ['normal', '74.57627118644068'],
#        ['normal', '81.5028901734104'],
#        ['fat lv3', '80.88235294117646'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['fat lv1', '67.41573033707866'],
#        ['normal', '74.57627118644068'],
#        ['normal', '74.57627118644068'],
#        ['fat lv1', '67.41573033707866'],
#        ['fat lv1', '67.41573033707866'],
#        ['fat lv1', '67.41573033707866'],
#        ['normal', '74.57627118644068'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '68.0'],
#        ['fat lv3', '80.88235294117646'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '57.4468085106383'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '57.4468085106383'],
#        ['thin', '81.25'],
#        ['normal', '74.57627118644068'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv1', '73.4375'],
#        ['fat lv1', '73.4375'],
#        ['thin', '81.25'],
#        ['fat lv2', '68.0'],
#        ['normal', '81.5028901734104'],
#        ['fat lv1', '67.41573033707866'],
#        ['thin', '81.25'],
#        ['fat lv1', '73.4375'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['normal', '90.0'],
#        ['fat lv3', '80.88235294117646'],
#        ['fat lv2', '57.4468085106383'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '57.4468085106383'],
#        ['normal', '74.57627118644068'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '68.0'],
#        ['fat lv2', '57.4468085106383'],
#        ['normal', '90.0'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '74.57627118644068'],
#        ['fat lv2', '57.4468085106383'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '74.57627118644068'],
#        ['fat lv3', '80.88235294117646'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '84.11214953271028'],
#        ['thin', '81.25'],
#        ['fat lv1', '67.41573033707866'],
#        ['fat lv2', '68.0'],
#        ['fat lv1', '67.41573033707866'],
#        ['normal', '90.0'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '68.0'],
#        ['fat lv2', '68.0'],
#        ['normal', '90.0'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '90.0'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '68.0'],
#        ['normal', '74.57627118644068'],
#        ['fat lv3', '80.88235294117646'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv1', '73.4375'],
#        ['fat lv2', '57.4468085106383'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '57.4468085106383'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '81.5028901734104'],
#        ['fat lv1', '67.41573033707866'],
#        ['normal', '81.5028901734104'],
#        ['fat lv1', '67.41573033707866'],
#        ['normal', '74.57627118644068'],
#        ['fat lv3', '80.88235294117646'],
#        ['fat lv2', '57.4468085106383'],
#        ['fat lv2', '68.0'],
#        ['normal', '74.57627118644068'],
#        ['normal', '81.5028901734104'],
#        ['fat lv3', '80.88235294117646'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '57.4468085106383'],
#        ['fat lv1', '67.41573033707866'],
#        ['normal', '81.5028901734104'],
#        ['fat lv3', '80.88235294117646'],
#        ['fat lv1', '67.41573033707866'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv2', '57.4468085106383'],
#        ['fat lv1', '73.4375'],
#        ['thin', '81.25'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '57.4468085106383'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '57.4468085106383'],
#        ['normal', '90.0'],
#        ['fat lv2', '84.11214953271028'],
#        ['fat lv3', '80.88235294117646'],
#        ['normal', '74.57627118644068'],
#        ['thin', '81.25'],
#        ['normal', '74.57627118644068'],
#        ['normal', '81.5028901734104'],
#        ['normal', '81.5028901734104'],
#        ['fat lv2', '57.4468085106383'],
#        ['fat lv3', '80.88235294117646'],
#        ['fat lv1', '73.4375'],
#        ['normal', '74.57627118644068'],
#        ['fat lv2', '57.4468085106383'],
#        ['fat lv2', '57.4468085106383'],
#        ['thin', '81.25'],
#        ['fat lv1', '73.4375'],
#        ['fat lv2', '84.11214953271028'],
#        ['normal', '81.5028901734104']], dtype='<U17')

# %%
error_Test = find_error_classification(Y_Test, Yhat_Test[:, 0:1])

# %%
error_Test
# Out:
# 30.0
