# %%
import nbimporter
import myai as ai

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Importing Jupyter notebook from myai.ipynb

# %%
Data = pd.read_excel('price feature 5 timestep target 3 timestep.xlsx')

# %%
Data
# Out:
#              h5        l5        h4        l4        h3        l3        h2  \
# 0      1.146468  1.146288  1.146666  1.146576  1.146509  1.146392  1.146159
# 1      1.146666  1.146576  1.146509  1.146392  1.146159  1.145967  1.145842
# 2      1.146509  1.146392  1.146159  1.145967  1.145842  1.145704  1.145568
# 3      1.146159  1.145967  1.145842  1.145704  1.145568  1.145446  1.145330
# 4      1.145842  1.145704  1.145568  1.145446  1.145330  1.145190  1.145338
# 5      1.145568  1.145446  1.145330  1.145190  1.145338  1.145193  1.144891
# 6      1.145330  1.145190  1.145338  1.145193  1.144891  1.144770  1.145237
# 7      1.145338  1.145193  1.144891  1.144770  1.145237  1.145089  1.145210
# 8      1.144891  1.144770  1.145237  1.145089  1.145210  1.145017  1.144859
# 9      1.145237  1.145089  1.145210  1.145017  1.144859  1.144687  1.144561
# 10     1.145210  1.145017  1.144859  1.144687  1.144561  1.144405  1.144674
# 11     1.144859  1.144687  1.144561  1.144405  1.144674  1.144546  1.144693
# 12     1.144561  1.144405  1.144674  1.144546  1.144693  1.144545  1.144541
# 13     1.144674  1.144546  1.144693  1.144545  1.144541  1.144414  1.144627
# 14     1.144693  1.144545  1.144541  1.144414  1.144627  1.144483  1.145184
# 15     1.144541  1.144414  1.144627  1.144483  1.145184  1.145023  1.146124
# 16     1.144627  1.144483  1.145184  1.145023  1.146124  1.145938  1.146932
# 17     1.145184  1.145023  1.146124  1.145938  1.146932  1.146766  1.147477
# 18     1.146124  1.145938  1.146932  1.146766  1.147477  1.147293  1.148344
# 19     1.146932  1.146766  1.147477  1.147293  1.148344  1.148143  1.149074
# 20     1.147477  1.147293  1.148344  1.148143  1.149074  1.148810  1.149307
# 21     1.148344  1.148143  1.149074  1.148810  1.149307  1.149119  1.149380
# 22     1.149074  1.148810  1.149307  1.149119  1.149380  1.149121  1.149159
# 23     1.149307  1.149119  1.149380  1.149121  1.149159  1.148932  1.148690
# 24     1.149380  1.149121  1.149159  1.148932  1.148690  1.148421  1.148883
# 25     1.149159  1.148932  1.148690  1.148421  1.148883  1.148618  1.148861
# 26     1.148690  1.148421  1.148883  1.148618  1.148861  1.148579  1.148864
# 27     1.148883  1.148618  1.148861  1.148579  1.148864  1.148567  1.148479
# 28     1.148861  1.148579  1.148864  1.148567  1.148479  1.148302  1.148193
# 29     1.148864  1.148567  1.148479  1.148302  1.148193  1.148000  1.148159
# ...         ...       ...       ...       ...       ...       ...       ...
# 32155  1.103996  1.103873  1.104100  1.103972  1.104430  1.104322  1.104704
# 32156  1.104100  1.103972  1.104430  1.104322  1.104704  1.104619  1.104910
# 32157  1.104430  1.104322  1.104704  1.104619  1.104910  1.104797  1.104941
# 32158  1.104704  1.104619  1.104910  1.104797  1.104941  1.104841  1.105180
# 32159  1.104910  1.104797  1.104941  1.104841  1.105180  1.105035  1.105354
# 32160  1.104941  1.104841  1.105180  1.105035  1.105354  1.105260  1.105322
# 32161  1.105180  1.105035  1.105354  1.105260  1.105322  1.105216  1.105378
# 32162  1.105354  1.105260  1.105322  1.105216  1.105378  1.105239  1.105265
# 32163  1.105322  1.105216  1.105378  1.105239  1.105265  1.105159  1.105182
# 32164  1.105378  1.105239  1.105265  1.105159  1.105182  1.105077  1.105204
# 32165  1.105265  1.105159  1.105182  1.105077  1.105204  1.105094  1.105188
# 32166  1.105182  1.105077  1.105204  1.105094  1.105188  1.105050  1.104886
# 32167  1.105204  1.105094  1.105188  1.105050  1.104886  1.104779  1.104845
# 32168  1.105188  1.105050  1.104886  1.104779  1.104845  1.104735  1.104595
# 32169  1.104886  1.104779  1.104845  1.104735  1.104595  1.104490  1.104447
# 32170  1.104845  1.104735  1.104595  1.104490  1.104447  1.104357  1.104581
# 32171  1.104595  1.104490  1.104447  1.104357  1.104581  1.104477  1.104625
# 32172  1.104447  1.104357  1.104581  1.104477  1.104625  1.104547  1.105039
# 32173  1.104581  1.104477  1.104625  1.104547  1.105039  1.104934  1.105271
# 32174  1.104625  1.104547  1.105039  1.104934  1.105271  1.105184  1.105214
# 32175  1.105039  1.104934  1.105271  1.105184  1.105214  1.105133  1.105374
# 32176  1.105271  1.105184  1.105214  1.105133  1.105374  1.105286  1.105314
# 32177  1.105214  1.105133  1.105374  1.105286  1.105314  1.105211  1.105398
# 32178  1.105374  1.105286  1.105314  1.105211  1.105398  1.105328  1.105536
# 32179  1.105314  1.105211  1.105398  1.105328  1.105536  1.105455  1.105527
# 32180  1.105398  1.105328  1.105536  1.105455  1.105527  1.105431  1.105530
# 32181  1.105536  1.105455  1.105527  1.105431  1.105530  1.105465  1.105427
# 32182  1.105527  1.105431  1.105530  1.105465  1.105427  1.105365  1.105384
# 32183  1.105530  1.105465  1.105427  1.105365  1.105384  1.105288  1.105475
# 32184  1.105427  1.105365  1.105384  1.105288  1.105475  1.105418  1.105417
#
#              l2        h1        l1   target3   target2   target1
# 0      1.145967  1.145842  1.145704  1.146159  1.145842  1.145568
# 1      1.145704  1.145568  1.145446  1.145842  1.145568  1.145330
# 2      1.145446  1.145330  1.145190  1.145568  1.145330  1.145338
# 3      1.145190  1.145338  1.145193  1.145330  1.145338  1.144891
# 4      1.145193  1.144891  1.144770  1.145338  1.144891  1.145237
# 5      1.144770  1.145237  1.145089  1.144891  1.145237  1.145210
# 6      1.145089  1.145210  1.145017  1.145237  1.145210  1.144859
# 7      1.145017  1.144859  1.144687  1.145210  1.144859  1.144561
# 8      1.144687  1.144561  1.144405  1.144859  1.144561  1.144674
# 9      1.144405  1.144674  1.144546  1.144561  1.144674  1.144693
# 10     1.144546  1.144693  1.144545  1.144674  1.144693  1.144541
# 11     1.144545  1.144541  1.144414  1.144693  1.144541  1.144627
# 12     1.144414  1.144627  1.144483  1.144541  1.144627  1.145184
# 13     1.144483  1.145184  1.145023  1.144627  1.145184  1.146124
# 14     1.145023  1.146124  1.145938  1.145184  1.146124  1.146932
# 15     1.145938  1.146932  1.146766  1.146124  1.146932  1.147477
# 16     1.146766  1.147477  1.147293  1.146932  1.147477  1.148344
# 17     1.147293  1.148344  1.148143  1.147477  1.148344  1.149074
# 18     1.148143  1.149074  1.148810  1.148344  1.149074  1.149307
# 19     1.148810  1.149307  1.149119  1.149074  1.149307  1.149380
# 20     1.149119  1.149380  1.149121  1.149307  1.149380  1.149159
# 21     1.149121  1.149159  1.148932  1.149380  1.149159  1.148690
# 22     1.148932  1.148690  1.148421  1.149159  1.148690  1.148883
# 23     1.148421  1.148883  1.148618  1.148690  1.148883  1.148861
# 24     1.148618  1.148861  1.148579  1.148883  1.148861  1.148864
# 25     1.148579  1.148864  1.148567  1.148861  1.148864  1.148479
# 26     1.148567  1.148479  1.148302  1.148864  1.148479  1.148193
# 27     1.148302  1.148193  1.148000  1.148479  1.148193  1.148159
# 28     1.148000  1.148159  1.147956  1.148193  1.148159  1.147881
# 29     1.147956  1.147881  1.147690  1.148159  1.147881  1.147632
# ...         ...       ...       ...       ...       ...       ...
# 32155  1.104619  1.104910  1.104797  1.104704  1.104910  1.104941
# 32156  1.104797  1.104941  1.104841  1.104910  1.104941  1.105180
# 32157  1.104841  1.105180  1.105035  1.104941  1.105180  1.105354
# 32158  1.105035  1.105354  1.105260  1.105180  1.105354  1.105322
# 32159  1.105260  1.105322  1.105216  1.105354  1.105322  1.105378
# 32160  1.105216  1.105378  1.105239  1.105322  1.105378  1.105265
# 32161  1.105239  1.105265  1.105159  1.105378  1.105265  1.105182
# 32162  1.105159  1.105182  1.105077  1.105265  1.105182  1.105204
# 32163  1.105077  1.105204  1.105094  1.105182  1.105204  1.105188
# 32164  1.105094  1.105188  1.105050  1.105204  1.105188  1.104886
# 32165  1.105050  1.104886  1.104779  1.105188  1.104886  1.104845
# 32166  1.104779  1.104845  1.104735  1.104886  1.104845  1.104595
# 32167  1.104735  1.104595  1.104490  1.104845  1.104595  1.104447
# 32168  1.104490  1.104447  1.104357  1.104595  1.104447  1.104581
# 32169  1.104357  1.104581  1.104477  1.104447  1.104581  1.104625
# 32170  1.104477  1.104625  1.104547  1.104581  1.104625  1.105039
# 32171  1.104547  1.105039  1.104934  1.104625  1.105039  1.105271
# 32172  1.104934  1.105271  1.105184  1.105039  1.105271  1.105214
# 32173  1.105184  1.105214  1.105133  1.105271  1.105214  1.105374
# 32174  1.105133  1.105374  1.105286  1.105214  1.105374  1.105314
# 32175  1.105286  1.105314  1.105211  1.105374  1.105314  1.105398
# 32176  1.105211  1.105398  1.105328  1.105314  1.105398  1.105536
# 32177  1.105328  1.105536  1.105455  1.105398  1.105536  1.105527
# 32178  1.105455  1.105527  1.105431  1.105536  1.105527  1.105530
# 32179  1.105431  1.105530  1.105465  1.105527  1.105530  1.105427
# 32180  1.105465  1.105427  1.105365  1.105530  1.105427  1.105384
# 32181  1.105365  1.105384  1.105288  1.105427  1.105384  1.105475
# 32182  1.105288  1.105475  1.105418  1.105384  1.105475  1.105417
# 32183  1.105418  1.105417  1.105367  1.105475  1.105417  1.105335
# 32184  1.105367  1.105335  1.105268  1.105417  1.105335  1.105422
#
# [32185 rows x 13 columns]

# %% [markdown]
# ### 1.1 change dataframe to matrix

# %%
DataMatrix = Data.values

# %%
np.random.shuffle(DataMatrix)

# %% [markdown]
# ### 1.2 split matrix to X and Y

# %%
N = DataMatrix.shape[0]

# %%
D = DataMatrix.shape[1] - 3

# %%
X = DataMatrix[:, :D]
Y = DataMatrix[:, D:]

# %% [markdown]
# ### 1.3 split data to training set and test set

# %%
start = 0
end = int(0.8*N)

# %%
X_train = np.array(X[start:end, :], dtype='float32')
Y_train = np.array(Y[start:end, :], dtype='float32')

X_test = np.array(X[end:, :], dtype='float32')
Y_test = np.array(Y[end:, :], dtype='float32')

# %% [markdown]
# ### 1.4 normalize X and Y

# %%
norm_X = ai.Normalize(X_train, norm_type='minmaxNorm')
norm_Y = ai.Normalize(Y_train, norm_type='minmaxNorm')

# %%
X_train_norm = norm_X.fit(X_train)
Y_train_norm = norm_Y.fit(Y_train)

# %%
X_test_norm = norm_X.fit(X_test)
Y_test_norm = norm_Y.fit(Y_test)

# %% [markdown]
# ## 2. Create Model

# %% [markdown]
# ### 2.1 learn

# %%
regr = ai.GRU(n_ts_feature=5, n_ts_target=3, RNN_HL=[3], ANN_HL=[2, 1], ANN_AF=['sigmoid', ['prelu', 0.5]])

# %%
regr.fit(X_train_norm, Y_train_norm, 'mse', epoch=200, learning_rate=0.05)

# %%
plt.plot(regr.loss_list)

# %% [markdown]
# ### 2.2 model evaluation for training set

# %%
Yhat_train_norm = regr.predict(X_train_norm)

# %%
n_rows_yhat_train = Yhat_train_norm[0].data.shape[0]
_Yhat_train_norm = np.empty([n_rows_yhat_train, 0], dtype=float)
for i in range(regr.n_ts_target):
    _Yhat_train_norm = np.hstack([_Yhat_train_norm, Yhat_train_norm[i].data])

# %%
Yhat_train = norm_Y.transform(_Yhat_train_norm)

# %%
Yhat_train_TS = ai.RNN.seperate_timestep(Yhat_train, regr.n_ts_target)

# %%
Y_train_TS = ai.RNN.seperate_timestep(Y_train, regr.n_ts_target)

# %%
for i in range(regr.n_ts_target):
    print('timestep :', i+1)
    print(ai.ErrorScore.find_error(Y_train_TS[i], Yhat_train_TS[i], 'MSE'))
# Out:
# timestep : 1
# 0.00014643751952571555
# timestep : 2
# 0.00014312337921389004
# timestep : 3
# 0.00014218078720311663

# %%
for i in range(regr.n_ts_target):
    print('timestep :', i+1)
    plt.scatter(Yhat_train_TS[i], Y_train_TS[i])
    plt.plot()
# Out:
# timestep : 1
# timestep : 2
# timestep : 3

# %% [markdown]
# ## 3. Making Prediction

# %% [markdown]
# ### 3.1 Predict

# %%
Yhat_test_norm = regr.predict(X_test_norm)

# %%
n_rows_yhat_test = Yhat_test_norm[0].data.shape[0]
_Yhat_test_norm = np.empty([n_rows_yhat_test, 0], dtype=float)
for i in range(regr.n_ts_target):
    _Yhat_test_norm = np.hstack([_Yhat_test_norm, Yhat_test_norm[i].data])

# %%
Yhat_test = norm_Y.transform(_Yhat_test_norm)

# %%
Yhat_test_TS = ai.RNN.seperate_timestep(Yhat_test, regr.n_ts_target)

# %% [markdown]
# ### 3.2 model evaluation for test set

# %%
Y_test_TS = ai.RNN.seperate_timestep(Y_test, regr.n_ts_target)

# %%
for i in range(regr.n_ts_target):
    print('timestep :', i+1)
    print(ai.ErrorScore.find_error(Y_test_TS[i], Yhat_test_TS[i], 'MSE'))
# Out:
# timestep : 1
# 0.00014213450920519491
# timestep : 2
# 0.0001389355852327406
# timestep : 3
# 0.0001380624403621926

# %%
for i in range(regr.n_ts_target):
    print('timestep :', i+1)
    plt.scatter(Yhat_test_TS[i], Y_test_TS[i])
    plt.plot()
# Out:
# timestep : 1
# timestep : 2
# timestep : 3
