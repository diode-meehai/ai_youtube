# %%
import nbimporter
import myai as ai

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Importing Jupyter notebook from myai.ipynb

# %%
Data = pd.read_csv('Wongnai Word2Vec.csv')

# %%
Data
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 1   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 2   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 3   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 4   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 5   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 6   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 7   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 8   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 9   -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 10  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 11  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 12  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 13  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 14  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 15  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 16  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 17  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 18  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 19  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 20  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 21  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 22  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 23  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 24  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 25  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 26  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 27  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 28  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 29  -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# ..        ...       ...       ...       ...       ...       ...       ...
# 970 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 971 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 972 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 973 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 974 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 975 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 976 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 977 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 978 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 979 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 980 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 981 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 982 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 983 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 984 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 985 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 986 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 987 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 988 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 989 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 990 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 991 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 992 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 993 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 994 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 995  0.292322 -0.460228  0.356694 -0.561057  0.285655 -0.444607 -0.082833
# 996 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 997 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 998 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
# 999 -0.239316  0.118631 -0.239316  0.118631 -0.239316  0.118631 -0.239316
#
#             7         8         9  ...       185       186       187  \
# 0    0.118631 -0.239316  0.118631  ... -0.226666  0.016094 -0.208605
# 1    0.118631 -0.239316  0.118631  ... -0.152745  0.124475 -0.226666
# 2    0.118631 -0.239316  0.118631  ... -0.226666  0.219977 -0.518427
# 3    0.118631 -0.239316  0.118631  ... -0.152745  0.077001 -0.156106
# 4    0.118631 -0.239316  0.118631  ... -0.342199  1.132376  0.308303
# 5    0.118631 -0.239316  0.118631  ... -0.488117  0.275248 -0.540330
# 6    0.118631 -0.239316  0.118631  ... -0.380017  0.009236 -0.281256
# 7    0.118631 -0.239316  0.118631  ... -0.639385  0.033286 -0.235618
# 8    0.118631 -0.239316  0.118631  ... -0.241496  0.125416 -0.239233
# 9    0.118631 -0.239316  0.118631  ... -0.274204  0.320011 -0.575766
# 10   0.118631 -0.239316  0.118631  ...  0.118631  0.374960  0.612771
# 11   0.118631 -0.239316  0.118631  ... -0.575766  0.271384 -0.435603
# 12   0.118631 -0.239316  0.118631  ... -0.540330  0.137932 -0.290743
# 13   0.118631 -0.239316  0.118631  ... -0.435603  1.001052  0.383122
# 14   0.118631 -0.239316  0.118631  ... -0.639385  0.106329 -0.349669
# 15   0.118631 -0.239316  0.118631  ... -0.397815  0.271384 -0.435603
# 16   0.118631 -0.239316  0.118631  ... -0.561057  0.266662 -0.439642
# 17   0.118631 -0.239316  0.118631  ... -0.266300  1.198746  0.426733
# 18   0.118631 -0.239316  0.118631  ...  0.383122  0.075292 -0.458600
# 19   0.118631 -0.239316  0.118631  ... -0.564011 -0.076427 -0.040739
# 20   0.118631 -0.239316  0.118631  ...  0.435913  0.321462 -0.490165
# 21   0.118631 -0.239316  0.118631  ...  0.435913  0.307641 -0.450955
# 22   0.118631 -0.239316  0.118631  ...  0.305050  0.342998 -0.509260
# 23   0.118631 -0.239316  0.118631  ... -0.470559  0.246349 -0.366908
# 24   0.118631 -0.239316  0.118631  ...  0.435913  0.431431 -0.346904
# 25   0.118631 -0.239316  0.118631  ...  0.347879  0.206412 -0.373808
# 26   0.118631 -0.239316  0.118631  ...  0.347879  0.030202 -0.241496
# 27   0.118631 -0.239316  0.118631  ... -0.547500  1.271622  0.614183
# 28   0.118631 -0.239316  0.118631  ... -0.156390 -0.192004  0.015465
# 29   0.118631 -0.239316  0.118631  ... -0.316728  0.047696 -0.288070
# ..        ...       ...       ...  ...       ...       ...       ...
# 970  0.118631 -0.239316  0.118631  ... -0.161200 -0.171534 -0.029617
# 971  0.118631 -0.239316  0.118631  ... -0.289506  0.363327 -0.448110
# 972  0.118631 -0.239316  0.118631  ... -0.123840  0.297508 -0.491487
# 973  0.118631 -0.239316  0.118631  ... -0.561057  1.001052  0.383122
# 974  0.118631 -0.239316  0.118631  ...  0.383122  0.178575 -0.390787
# 975  0.118631 -0.239316  0.118631  ... -0.512343  0.071282 -0.400480
# 976  0.118631 -0.239316  0.118631  ...  0.383122  0.009097 -0.146598
# 977  0.118631 -0.239316  0.118631  ...  0.376936  0.184871 -0.485874
# 978  0.118631 -0.239316  0.118631  ...  0.383122  0.174409 -0.448384
# 979  0.118631 -0.239316  0.118631  ... -0.139839  0.323803 -0.545013
# 980  0.118631 -0.239316  0.118631  ... -0.508399  0.223399  0.662441
# 981  0.118631 -0.239316  0.118631  ... -0.561057  0.210413 -0.412732
# 982  0.118631 -0.239316  0.118631  ... -0.077839  0.313742 -0.315823
# 983  0.118631 -0.239316  0.118631  ... -0.211686  0.356694 -0.561057
# 984  0.118631 -0.239316  0.118631  ... -0.142107  0.167959 -0.506782
# 985  0.118631 -0.239316  0.118631  ... -0.170548  0.280074 -0.411119
# 986  0.118631 -0.239316  0.118631  ... -0.281256  0.077001 -0.156106
# 987  0.118631 -0.239316  0.118631  ... -0.139839  0.286838 -0.508399
# 988  0.118631 -0.239316  0.118631  ...  0.315130  0.208080 -0.450928
# 989  0.118631 -0.239316  0.118631  ... -0.239233  0.734681  0.334113
# 990  0.118631 -0.239316  0.118631  ... -0.564011  0.137932 -0.290743
# 991  0.118631 -0.239316  0.118631  ... -0.642148  0.206412 -0.373808
# 992  0.118631 -0.239316  0.118631  ... -0.123840  0.267143 -0.399754
# 993  0.118631 -0.239316  0.118631  ... -0.473564  0.271384 -0.435603
# 994  0.118631 -0.239316  0.118631  ...  0.080202  0.130784 -0.359183
# 995 -0.108668  0.206412 -0.373808  ... -0.575766  1.235186  0.456846
# 996  0.118631 -0.239316  0.118631  ... -0.311840 -0.018329 -0.152582
# 997  0.118631 -0.239316  0.118631  ... -0.501870  0.144967 -0.003717
# 998  0.118631 -0.239316  0.118631  ... -0.506782  0.162347 -0.455784
# 999  0.118631 -0.239316  0.118631  ... -0.561057  0.311978 -0.501870
#
#           188       189       190       191       192       193  target
# 0   -0.109032 -0.130672 -0.036423 -0.176314  0.177451 -0.475218     4.0
# 1    0.338893 -0.611316  0.167099 -0.470559  0.285370 -0.514478     5.0
# 2    0.033701 -0.209102  1.229286  0.305050  0.032246 -0.244700     3.0
# 3    0.124475 -0.226666  1.132376  0.308303  0.075021  0.599291     5.0
# 4    0.078759 -0.228896  0.285370 -0.514478  1.229286  0.305050     5.0
# 5    0.137932 -0.290743  0.078759 -0.228896  0.113616  0.767474     4.0
# 6    0.356694 -0.561057  0.316406 -0.639385  0.390034  0.622228     5.0
# 7    0.387138 -0.467263  1.327197  0.390764  0.083834 -0.274204     3.0
# 8    0.023732 -0.247107  0.288791 -0.356685  0.390034  0.622228     4.0
# 9    0.044358 -0.038790  0.266662 -0.439642  0.338893 -0.611316     1.0
# 10  -0.171070  0.020198 -0.169296 -0.057883  0.681386  0.861419     5.0
# 11   0.182599 -0.525391  0.075644 -0.140590  0.390034  0.622228     4.0
# 12   1.060184  0.774234  0.086935 -0.327510  0.099660  0.083869     4.0
# 13   0.206412 -0.373808  0.067177 -0.132684  1.002240  0.498886     4.0
# 14   0.124475 -0.226666  1.235186  0.456846  0.630384  0.547620     3.0
# 15   0.124475 -0.226666  0.177135 -0.344990  0.204184 -0.472657     5.0
# 16   0.301110 -0.218578  0.257729 -0.436990  1.229286  0.305050     4.0
# 17   0.144430 -0.137123 -0.045478 -0.122738  0.753076  0.597516     4.0
# 18   0.354896 -0.488117  0.072536 -0.239905  0.157491 -0.325926     4.0
# 19   0.286109 -0.364947 -0.198189  0.076704 -0.000197 -0.011181     3.0
# 20   0.943651  0.444471  0.764234  0.845649  0.190575 -0.122288     3.0
# 21   1.033281  0.471335  0.356694 -0.561057  0.280074 -0.411119     5.0
# 22   0.338893 -0.611316 -0.049686  0.017922  0.271547 -0.385045     3.0
# 23   0.085656 -0.262841  0.010242 -0.267944  0.706132  0.929787     3.0
# 24   0.321462 -0.490165  0.943651  0.444471  0.271384 -0.435603     3.0
# 25   0.285370 -0.514478  0.338893 -0.611316 -0.153462  0.183366     4.0
# 26   0.321462 -0.490165  0.174120 -0.404375  0.338893 -0.611316     3.0
# 27   0.278731 -0.324474  0.246728 -0.286504  0.309414  0.061647     4.0
# 28   0.219977 -0.518427  0.117405 -0.362824  1.229286  0.305050     4.0
# 29   1.229286  0.305050  1.001052  0.383122  0.070022 -0.296081     4.0
# ..        ...       ...       ...       ...       ...       ...     ...
# 970  0.315451 -0.316195 -0.008287 -0.113403  0.359173 -0.385201     1.0
# 971  0.356694 -0.561057 -0.008287 -0.113403  0.320011 -0.575766     1.0
# 972  0.062550 -0.243724 -0.036423 -0.176314  1.235186  0.456846     1.0
# 973  0.125416 -0.239233  0.124119 -0.172770  0.062354 -0.139839     1.0
# 974  0.271384 -0.435603  0.985660  0.458877  0.014369 -0.246440     1.0
# 975  0.069966 -0.339161  0.338893 -0.611316  1.235186  0.456846     1.0
# 976  0.058433 -0.196414  0.062354 -0.139839  0.078759 -0.228896     1.0
# 977 -0.111757 -0.052107  0.320011 -0.575766  0.292881  0.154887     1.0
# 978  0.348024  0.547104  0.797878  0.863535  0.236543 -0.533642     1.0
# 979  0.563142 -0.584887  1.057542  0.435913  0.081181 -0.244016     1.0
# 980  0.356694 -0.561057  1.001052  0.383122  0.301205  0.686248     1.0
# 981  0.162347 -0.455784  0.065462 -0.272098 -0.056731 -0.159231     1.0
# 982 -0.054376 -0.005370  1.198746  0.426733  0.078759 -0.228896     1.0
# 983  0.033905 -0.226334  0.062550 -0.243724  0.234965 -0.499281     1.0
# 984 -0.124041 -0.092709  1.198746  0.426733  0.078759 -0.228896     1.0
# 985  1.057542  0.435913 -0.053749 -0.246598  0.286838 -0.508399     1.0
# 986  0.312907 -0.467913  1.229286  0.305050  0.563142 -0.584887     1.0
# 987  1.280613  0.315130  1.254349  0.291111  0.177135 -0.344990     1.0
# 988 -0.069254 -0.161760  0.563142 -0.584887  1.229286  0.305050     1.0
# 989  0.363327 -0.448110  0.124475 -0.226666  0.097446 -0.349823     1.0
# 990  1.159068  0.287863  1.057542  0.435913  0.211549 -0.363216     1.0
# 991  0.306530 -0.517880  1.057542  0.435913  0.320011 -0.575766     1.0
# 992  0.356694 -0.561057  0.316406 -0.639385  0.564573  0.538721     1.0
# 993  0.009765 -0.176765  0.086935 -0.327510  1.235186  0.456846     1.0
# 994 -0.018450 -0.174840 -0.043050 -0.014617  0.564573  0.538721     1.0
# 995  0.208482 -0.460351  1.159068  0.287863  1.183545  0.307823     1.0
# 996  0.390034  0.622228  0.354896 -0.488117 -0.091203 -0.127518     1.0
# 997  0.320011 -0.575766  0.149858 -0.356578  0.011527 -0.211686     1.0
# 998 -0.100440 -0.123840  0.338893 -0.611316  0.271384 -0.435603     1.0
# 999  0.204184 -0.472657  0.086935 -0.327510  0.246728 -0.286504     1.0
#
# [1000 rows x 195 columns]

# %% [markdown]
# ### 1.1 change dataframe to matrix

# %%
DataMatrix = Data.values

# %%
np.random.shuffle(DataMatrix)

# %% [markdown]
# ### 1.2 split matrix to X and Y

# %%
N = DataMatrix.shape[0]

# %%
D = DataMatrix.shape[1] - 1

# %%
X = DataMatrix[:, :D]
Y = ai.Preprocessing.create_one_hot_matrix(DataMatrix[:, D:])

# %% [markdown]
# ### 1.3 split data to training set and test set

# %%
start = 0
end = int(0.8*N)

# %%
X_train = np.array(X[start:end, :], dtype='float32')
Y_train = np.array(Y[start:end, :], dtype='float32')

X_test = np.array(X[end:, :], dtype='float32')
Y_test = np.array(Y[end:, :], dtype='float32')

# %% [markdown]
# ### 1.4 normalize X and Y

# %%
norm_X = ai.Normalize(X_train, norm_type='minmaxNorm')
norm_Y = ai.Normalize(Y_train, norm_type='minmaxNorm')

# %%
X_train_norm = norm_X.fit(X_train)
Y_train_norm = norm_Y.fit(Y_train)

# %%
X_test_norm = norm_X.fit(X_test)
Y_test_norm = norm_Y.fit(Y_test)

# %% [markdown]
# ## 2. Create Model

# %% [markdown]
# ### 2.1 learn

# %%
regr = ai.RNN(n_ts_feature=97, n_ts_target=1, RNN_HL=[3], ANN_HL=[2, 5], ANN_AF=[['prelu', 0.5], 'softmax'])

# %%
regr.fit(X_train_norm, Y_train_norm, 'm_entropy', epoch=200, learning_rate=1)

# %%
plt.plot(regr.loss_list)

# %% [markdown]
# ### 2.2 model evaluation for training set

# %%
Yhat_train_norm = regr.predict(X_train_norm)

# %%
n_rows_yhat_train = Yhat_train_norm[0].data.shape[0]
_Yhat_train_norm = np.empty([n_rows_yhat_train, 0], dtype=float)
for i in range(regr.n_ts_target):
    _Yhat_train_norm = np.hstack([_Yhat_train_norm, Yhat_train_norm[i].data])

# %%
Yhat_train = norm_Y.transform(_Yhat_train_norm)

# %%
Yhat_train_TS = ai.RNN.seperate_timestep(Yhat_train, regr.n_ts_target)

# %%
Y_train_TS = ai.RNN.seperate_timestep(Y_train, regr.n_ts_target)

# %%
for i in range(regr.n_ts_target):
    print('timestep :', i+1)
    print(ai.ErrorScore.find_error(Y_train_TS[i], Yhat_train_TS[i], 'multiclass'))

# %% [markdown]
# ## 3. Making Prediction

# %% [markdown]
# ### 3.1 Predict

# %%
Yhat_test_norm = regr.predict(X_test_norm)

# %%
n_rows_yhat_test = Yhat_test_norm[0].data.shape[0]
_Yhat_test_norm = np.empty([n_rows_yhat_test, 0], dtype=float)
for i in range(regr.n_ts_target):
    _Yhat_test_norm = np.hstack([_Yhat_test_norm, Yhat_test_norm[i].data])

# %%
Yhat_test = norm_Y.transform(_Yhat_test_norm)

# %%
Yhat_test_TS = ai.RNN.seperate_timestep(Yhat_test, regr.n_ts_target)

# %% [markdown]
# ### 3.2 model evaluation for test set

# %%
Y_test_TS = ai.RNN.seperate_timestep(Y_test, regr.n_ts_target)

# %%
for i in range(regr.n_ts_target):
    print('timestep :', i+1)
    print(ai.ErrorScore.find_error(Y_test_TS[i], Yhat_test_TS[i], 'multiclass'))
